# %%
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import pandas as pd
import os
from copy import copy
from collections import OrderedDict
from scipy.stats import spearmanr

# %%
MODEL_PATH = '../models/dim_bow500_10topics_firsttrack_artistactivedate'

# %%
# Load model
dim_model = DtmModel.load(MODEL_PATH)

# %%
# Load artist info
artists = pd.read_csv('../data/allmusic/artists_cleaned.csv')

# %%
# list of (artist_id, path) tuples
bow_path_by_artist = []

# Get paths to bow directories for each artist
BOW_DIR = '../data/features/bow_500/'

for artist_id in os.listdir(BOW_DIR):
    # Check if active_start is missing
    if int(np.isnan(float(artists[artists['id'] == int(artist_id)] ['active_start']))) == 0:
        # save (artist_id, path, active_start) tuple
        bow_path_by_artist.append((int(artist_id), BOW_DIR + artist_id + '/', int(artists[artists['id'] == int(artist_id)] ['active_start'])))

# Order list by active period start for artist
bow_path_by_artist.sort(key= lambda x: int(artists[artists['id'] == x[0]] ['active_start']))

# Create counter for number of songs for each decade of active_start
decade_counter = {int(k) : 0 for k in np.unique(artists['active_start'][~np.isnan(artists['active_start'])])}

for id, path, year in bow_path_by_artist:
    decade_counter[year] += 1

# Lookup table for time_slice index v. decade
time_slice_dict = {idx : year for (idx, year) in enumerate(sorted(decade_counter))}
# List of counts for each time slice for DIM
time_seq = [decade_counter[key] for key in sorted(decade_counter.keys())]

# %% [markdown]
# # Get most influential songs for each topic

# %%
# Create (num_songs, num_topics) array of influence scores
song_topic_inf_matrix = []

for time_idx in range(len(dim_model.time_slices)):    
    for song_idx in range(dim_model.time_slices[time_idx]):
        song_inf_by_topic = [None] * dim_model.num_topics

        for topic_idx in range(dim_model.num_topics):
            song_inf_by_topic[topic_idx] = dim_model.influences_time[time_idx][song_idx][topic_idx]
        
        song_topic_inf_matrix.append(song_inf_by_topic)

# %%
# Get the indices of the most influential songs per topic
most_inf_idx = np.array(song_topic_inf_matrix).argmax(axis=0)

for topic_no, artist_idx in enumerate(most_inf_idx):
    print "Topic:", topic_no
    # Lookup artist name
    print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
    # Lookup name of sample
    print os.listdir(bow_path_by_artist[artist_idx][1])[0]
    
    print
# Out:
# Topic: 0
# Sergey Rachmaninov
# 0_Prelude in C Sharp Minor Op. 32.npy
#
# Topic: 1
# Bert Williams
# 0_The Moon Shines on the Moonshine.npy
#
# Topic: 2
# Ferruccio Busoni
# 0_La La Campanella.npy
#
# Topic: 3
# Paul Dukas
# 0_Fantasmic! [From Fantasmic! (Disneyland)].npy
#
# Topic: 4
# Fisk University Jubilee Singers
# 0_God Bless the USA.npy
#
# Topic: 5
# Ferruccio Busoni
# 0_La La Campanella.npy
#
# Topic: 6
# Fisk University Jubilee Singers
# 0_God Bless the USA.npy
#
# Topic: 7
# Fisk University Jubilee Singers
# 0_God Bless the USA.npy
#
# Topic: 8
# Ferruccio Busoni
# 0_La La Campanella.npy
#
# Topic: 9
# Edgard Varèse
# 0_Poème Électronique.npy

# %% [markdown]
# # Get most influential songs per topic per epoch

# %%
song_topic_inf_by_decade = []
song_topic_inf_matrix_copy = copy(song_topic_inf_matrix)

# Slice song-topic matrix into list of submatrices keyed by time slice
for time_idx, num_in_slice in enumerate(dim_model.time_slices):
    song_topic_inf_by_decade.append(song_topic_inf_matrix_copy[:num_in_slice])
    del song_topic_inf_matrix_copy[:num_in_slice]

# %%
for idx, song_topic_matrix in enumerate(song_topic_inf_by_decade):
    print time_slice_dict[idx]
    print "==============================="
    
    # Get the indices of the most influential songs per topic
    # Note: Need to adjust indexing since index resets to 0 for each new decade
    most_inf_idx = np.array(song_topic_matrix).argmax(axis=0) + sum(dim_model.time_slices[:idx])

    for topic_no, artist_idx in enumerate(most_inf_idx):
        print "Topic:", topic_no
        # Lookup artist name
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
        # Lookup name of sample
        print os.listdir(bow_path_by_artist[artist_idx][1])[0]
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['main_genre'].iloc[0]
        print
# Out:
# 1890
# ===============================
# Topic: 0
# Sergey Rachmaninov
# 0_Prelude in C Sharp Minor Op. 32.npy
# Classical
#
# Topic: 1
# Camille Saint-Saëns
# 0_Aquarium.npy
# Classical
#
# Topic: 2
# Ferruccio Busoni
# 0_La La Campanella.npy
# Classical
#
# Topic: 3
# Paul Dukas
# 0_Fantasmic! [From Fantasmic! (Disneyland)].npy
# Classical
#
# Topic: 4
# Ferruccio Busoni
# 0_La La Campanella.npy
# Classical
#
# Topic: 5
# Ferruccio Busoni
# 0_La La Campanella.npy
# Classical
#
# Topic: 6
# Paul Dukas
# 0_Fantasmic! [From Fantasmic! (Disneyland)].npy
# Classical
#
# Topic: 7
# Ferruccio Busoni
# 0_La La Campanella.npy
# Classical
#
# Topic: 8
# Ferruccio Busoni
# 0_La La Campanella.npy
# Classical
#
# Topic: 9
# Ferruccio Busoni
# 0_La La Campanella.npy
# Classical
#
# 1900
# ===============================
# Topic: 0
# George Burns
# 0_The Jack Benny Program.npy
# Comedy/Spoken
#
# Topic: 1
# Bert Williams
# 0_The Moon Shines on the Moonshine.npy
# Vocal
#
# Topic: 2
# George Burns
# 0_The Jack Benny Program.npy
# Comedy/Spoken
#
# Topic: 3
# George Burns
# 0_The Jack Benny Program.npy
# Comedy/Spoken
#
# Topic: 4
# Fisk University Jubilee Singers
# 0_God Bless the USA.npy
# Religious
#
# Topic: 5
# Arnold Schoenberg
# 0_Sechs Kleine Klavierstücke.npy
# Classical
#
# Topic: 6
# Fisk University Jubilee Singers
# 0_God Bless the USA.npy
# Religious
#
# Topic: 7
# Fisk University Jubilee Singers
# 0_God Bless the USA.npy
# Religious
#
# Topic: 8
# Victor Herbert
# 0_Art Is Calling for Me (I Want to Be a Prima Donna).npy
# Stage & Screen
#
# Topic: 9
# George Burns
# 0_The Jack Benny Program.npy
# Comedy/Spoken
#
# 1910
# ===============================
# Topic: 0
# Blind Blake
# 0_Diddie Wa Diddie.npy
# Blues
#
# Topic: 1
# Edgard Varèse
# 0_Poème Électronique.npy
# Classical
#
# Topic: 2
# Zez Confrey
# 0_Kitten on the Keys.npy
# Easy Listening
#
# Topic: 3
# Frank Guarente
# 0_Charley, My boy.npy
# Vocal
#
# Topic: 4
# Edgard Varèse
# 0_Poème Électronique.npy
# Classical
#
# Topic: 5
# Whistler & His Jug Band
# 0_Low Down Blues.npy
# Blues
#
# Topic: 6
# Jim Jackson
# 0_Jim Jackson's Jamboree.npy
# Blues
#
# Topic: 7
# Whistler & His Jug Band
# 0_Low Down Blues.npy
# Blues
#
# Topic: 8
# Lead Belly
# 0_The Gallis Pole.npy
# Folk
#
# Topic: 9
# Edgard Varèse
# 0_Poème Électronique.npy
# Classical
#
# 1920
# ===============================
# Topic: 0
# Doc Cheatham
# 0_Avalon.npy
# Jazz
#
# Topic: 1
# Lucille Bogan
# 0_Coffee Grindin' Blues.npy
# Blues
#
# Topic: 2
# Kid Stormy Weather
# 0_Bread and Water Blues.npy
# Jazz
#
# Topic: 3
# Max Steiner
# 0_Gone With the Wind.npy
# Stage & Screen
#
# Topic: 4
# The Skillet Lickers
# 0_Casey Jones.npy
# Country
#
# Topic: 5
# The Skillet Lickers
# 0_Casey Jones.npy
# Country
#
# Topic: 6
# Doc Cheatham
# 0_Avalon.npy
# Jazz
#
# Topic: 7
# Sylvester Weaver
# 0_Garlic Blues.npy
# Blues
#
# Topic: 8
# Max Steiner
# 0_Gone With the Wind.npy
# Stage & Screen
#
# Topic: 9
# Henry Townsend
# 0_Tears Came Rollin' Down.npy
# Blues
#
# 1930
# ===============================
# Topic: 0
# Nathan Abshire
# 0_Pine Grove Blues.npy
# International
#
# Topic: 1
# Mezz Mezzrow
# 0_32 Bars of Blues.npy
# Jazz
#
# Topic: 2
# Buck Clayton
# 0_Hollywood Hangover.npy
# Jazz
#
# Topic: 3
# Buddy Tate
# 0_Back on the Street.npy
# Jazz
#
# Topic: 4
# Rufus Thomas
# 0_Bear Cat.npy
# R&B;
#
# Topic: 5
# Perry Como
# 0_(There's No Place Like) Home For the Holidays.npy
# Vocal
#
# Topic: 6
# Turk Murphy
# 0_Doctor Jazz.npy
# Jazz
#
# Topic: 7
# Jorge Negrete
# 0_Yo Soy Mexicano.npy
# Latin
#
# Topic: 8
# Jorge Negrete
# 0_Yo Soy Mexicano.npy
# Latin
#
# Topic: 9
# Etta Baker
# 0_Knoxville Rag.npy
# Blues
#
# 1940
# ===============================
# Topic: 0
# The Wilburn Brothers
# 0_Sparkling Brown Eyes.npy
# Country
#
# Topic: 1
# Jimmy Martin
# 0_Widow Maker.npy
# Country
#
# Topic: 2
# The Harmonizing Four
# 0_I Shall Not Be Moved.npy
# Religious
#
# Topic: 3
# Derroll Adams
# 0_Roll on Buddy.npy
# Folk
#
# Topic: 4
# Osvaldo Pugliese
# 0_Camorra III.npy
# Latin
#
# Topic: 5
# Walter Brown
# 0_Hootie Blues.npy
# Blues
#
# Topic: 6
# Buddy DeFranco
# 0_Joy Spring.npy
# Jazz
#
# Topic: 7
# Chico Hamilton
# 0_Fine and Mellow.npy
# Jazz
#
# Topic: 8
# J.C. Heard
# 0_What Is This Thing Called Love? (Norman Granz Jam Session).npy
# Jazz
#
# Topic: 9
# John Lee Hooker
# 0_Wandering Blues.npy
# Blues
#
# 1950
# ===============================
# Topic: 0
# Frank Morgan
# 0_Ten Cents a Dance.npy
# Jazz
#
# Topic: 1
# Clifton Chenier
# 0_Zydeco Cha Cha.npy
# International
#
# Topic: 2
# Jack Jones
# 0_Wives and Lovers.npy
# Vocal
#
# Topic: 3
# Johnny Horton
# 0_Honky Tonk Man.npy
# Country
#
# Topic: 4
# Dallas Frazier
# 0_The Laying on of Hands.npy
# Country
#
# Topic: 5
# David Baker
# 0_Somewhere in the Night.npy
# Jazz
#
# Topic: 6
# Urbie Green
# 0_The Blues Is Everybody's Buisness, Pt.2.npy
# Jazz
#
# Topic: 7
# Marty Wilde
# 0_Bad Boy.npy
# Pop/Rock
#
# Topic: 8
# Johnny Kidd
# 0_Shakin' All Over.npy
# Pop/Rock
#
# Topic: 9
# Eydie Gorme
# 0_Where or When.npy
# Vocal
#
# 1960
# ===============================
# Topic: 0
# Bob Marley & the Wailers
# 0_Soul Rebel.npy
# Reggae
#
# Topic: 1
# Peaches & Herb
# 0_Love Is Strange.npy
# R&B;
#
# Topic: 2
# Bob Marley & the Wailers
# 0_Soul Rebel.npy
# Reggae
#
# Topic: 3
# Barclay James Harvest
# 0_Poor Man's Moody Blues.npy
# Pop/Rock
#
# Topic: 4
# The Smoke
# 0_My Friend Jack.npy
# Pop/Rock
#
# Topic: 5
# The Mar-Keys
# 0_Last Night.npy
# R&B;
#
# Topic: 6
# Maria Bethânia
# 0_Sonho Meu.npy
# International
#
# Topic: 7
# Sam Bush
# 0_Step Inside This House (Step Inside My House).npy
# Country
#
# Topic: 8
# Kim Carnes
# 0_Don't Fall in Love With a Dreamer.npy
# Pop/Rock
#
# Topic: 9
# The Smoke
# 0_My Friend Jack.npy
# Pop/Rock
#
# 1970
# ===============================
# Topic: 0
# Trees
# 0_The Only Life for Me.npy
# Pop/Rock
#
# Topic: 1
# Matumbi
# 0_After Tonight.npy
# Reggae
#
# Topic: 2
# Labelle
# 0_On My Own.npy
# R&B;
#
# Topic: 3
# Greg Sage
# 0_My Vengeance.npy
# Pop/Rock
#
# Topic: 4
# Connie Crothers
# 0_Ballad No. 1.npy
# Jazz
#
# Topic: 5
# Miguel Bosé
# 0_Bambú.npy
# Latin
#
# Topic: 6
# Planxty
# 0_As I Roved Out.npy
# International
#
# Topic: 7
# The Meditations
# 0_Jesus Will See You Through.npy
# Reggae
#
# Topic: 8
# Steve Reid
# 0_She Likes to Watch.npy
# Jazz
#
# Topic: 9
# J.D. Souther
# 0_Her Town Too.npy
# Pop/Rock
#
# 1980
# ===============================
# Topic: 0
# Big Daddy Kinsey
# 0_Little Rain Falling.npy
# Blues
#
# Topic: 1
# Céline Dion
# 0_My Heart Will Go On.npy
# Pop/Rock
#
# Topic: 2
# Recoil
# 0_Prey.npy
# Pop/Rock
#
# Topic: 3
# Maggotron
# 0_Return of the Bass That Ate Miami.npy
# Rap
#
# Topic: 4
# Ty England
# 0_Should've Asked Her Faster.npy
# Country
#
# Topic: 5
# The Associates
# 0_Party Fears Two.npy
# Pop/Rock
#
# Topic: 6
# 14 Iced Bears
# 0_Inside.npy
# Pop/Rock
#
# Topic: 7
# Eric Bibb
# 0_If Our Hearts Ain't in It.npy
# Blues
#
# Topic: 8
# The Whitstein Brothers
# 0_Make Him a Soldier.npy
# Country
#
# Topic: 9
# The Ocean Blue
# 0_Sublime.npy
# Pop/Rock
#
# 1990
# ===============================
# Topic: 0
# DJ Krush
# 0_Duality.npy
# Electronic
#
# Topic: 1
# Chocolate Genius
# 0_Dang Me.npy
# Pop/Rock
#
# Topic: 2
# Madball
# 0_For My Enemies.npy
# Pop/Rock
#
# Topic: 3
# Trace Adkins
# 0_Honky Tonk Badonkadonk.npy
# Country
#
# Topic: 4
# Ivy
# 0_Digging Your Scene.npy
# Pop/Rock
#
# Topic: 5
# Afroman
# 0_Because I Got High.npy
# Rap
#
# Topic: 6
# Masta Ace Incorporated
# 0_Head Shop Mixtape [Continuous Mix].npy
# Rap
#
# Topic: 7
# Steelheart
# 0_I'll Never Let You Go.npy
# Pop/Rock
#
# Topic: 8
# Req
# 0_Rhythm 77.npy
# Electronic
#
# Topic: 9
# Laub
# 0_30 Grad.npy
# Electronic
#
# 2000
# ===============================
# Topic: 0
# AIDS Wolf
# 0_Letter to Al Johnson.npy
# Pop/Rock
#
# Topic: 1
# A.A. Bondy
# 0_Killed Myself When I Was Young.npy
# Pop/Rock
#
# Topic: 2
# Heliotropes
# 0_Wherever You Live.npy
# Pop/Rock
#
# Topic: 3
# Tapes 'n Tapes
# 0_Insistor.npy
# Pop/Rock
#
# Topic: 4
# Neon Trees
# 0_Sleeping With a Friend.npy
# Pop/Rock
#
# Topic: 5
# Fabulous Diamonds
# 0_[Untitled].npy
# Pop/Rock
#
# Topic: 6
# The Winnerys
# 0_In My Garden.npy
# Pop/Rock
#
# Topic: 7
# Robert Randolph & the Family Band
# 0_Brand New Wayo.npy
# Pop/Rock
#
# Topic: 8
# Alphabeat
# 0_Fascination.npy
# Pop/Rock
#
# Topic: 9
# Mono/Poly
# 0_Alpha & Omega.npy
# Electronic
#
# 2010
# ===============================
# Topic: 0
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 1
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 2
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 3
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 4
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 5
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 6
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 7
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 8
# PJ
# 0_Gangster.npy
# R&B;
#
# Topic: 9
# PJ
# 0_Gangster.npy
# R&B;

# %% [markdown]
# # Correlation with AllMusic Influence Graph Degree

# %%
# Calculate mean DIM influence per artist
mean_dim_influences = np.array(song_topic_inf_matrix).mean(axis=1)

# Get list of artist outdegrees in same order
artist_ids_ordered = [t[0] for t in bow_path_by_artist]
outdegrees_ordered = []

for id in artist_ids_ordered:
    outdegrees_ordered.append(artists[artists['id'] == id]['outdegree'].iloc[0])

# %%
# Calculate correlation
spearmanr(mean_dim_influences, outdegrees_ordered)
# Out:
# SpearmanrResult(correlation=0.016283108903372225, pvalue=0.050110958352326096)

# %% [markdown]
# # TODO: Baseline

# %% [markdown]
# # TODO: Breakdown by Genre
