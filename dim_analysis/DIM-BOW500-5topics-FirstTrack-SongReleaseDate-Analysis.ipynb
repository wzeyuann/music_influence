# %%
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import pandas as pd
import os
from copy import copy
from collections import OrderedDict
from scipy.stats import spearmanr
from tqdm import tqdm_notebook
import pickle

# %%
MODEL_PATH = '../models/dim_bow500_5topics_firsttrack_songreleasedate'
BOW_DIR = '../data/features/bow_500/'

# %%
# Load model
dim_model = DtmModel.load(MODEL_PATH)

# %%
# Load artist info
artists = pd.read_csv('../data/allmusic/artists_cleaned.csv')

# %%
# Load song info
songs = pd.read_csv('../data/artist_song_list_years_cleaned.csv')

# %%
# Load bow_path_by_artist
bow_path_by_artist = pickle.load(open('../models/bow500_path_by_artist.pk', 'rb'))

# %%
bow_path_by_artist_new = []

for (id, path, year) in bow_path_by_artist:
    bow_path_by_artist_new.append((id, BOW_DIR + path.split('/n/regal/rush_lab/xue/bow_500/')[1], year))

bow_path_by_artist = bow_path_by_artist_new

# %%
# # Add a column with a ".npy" extension
# songs['name_ext'] = songs['name_no_ext'].apply(lambda x: (x + '.npy')).str.decode('utf-8')

# # list of (artist_id, path, year) tuples
# bow_path_by_artist = []

# ids_in_songs = set(songs['artist_id'])

# for artist_id in tqdm_notebook(os.listdir(BOW_DIR)):
#     song_filename = os.listdir(BOW_DIR + artist_id)[0].decode('utf-8')
    
#     # Check if song year is missing or artist is missing from song df
#     if int(artist_id) in ids_in_songs and songs[songs['name_ext'] == song_filename]['year'].iloc[0] != 0:
#         # save (artist_id, path, year) tuple
#         bow_path_by_artist.append((int(artist_id), BOW_DIR + artist_id + '/', songs[songs['name_ext'] == song_filename]['year'].iloc[0]))

# print "Number of songs:", len(bow_path_by_artist)

# Order list by year
bow_path_by_artist.sort(key= lambda x: songs[songs['artist_id'] == x[0]]['year'].iloc[0])

# Create counter for number of songs for each year 
year_counter = {int(k) : 0 for k in np.unique(zip(*bow_path_by_artist)[2])}

for id, path, year in bow_path_by_artist:
    year_counter[year] += 1

# Lookup table for time_slice index v. year
time_slice_dict = {idx : year for (idx, year) in enumerate(sorted(year_counter))}
# List of counts for each time slice for DIM
time_seq = [year_counter[key] for key in sorted(year_counter.keys())]

print "Count of artists per each time slice:"
print time_seq
# Out:
# Count of artists per each time slice:
# [1, 1, 1, 1, 3, 1, 1, 1, 5, 3, 2, 2, 1, 2, 2, 1, 1, 2, 2, 5, 2, 2, 7, 2, 5, 5, 5, 6, 4, 6, 11, 15, 30, 42, 37, 64, 44, 44, 42, 52, 62, 49, 84, 73, 100, 113, 117, 112, 94, 135, 103, 133, 126, 131, 112, 141, 152, 167, 155, 156, 160, 141, 164, 171, 172, 182, 175, 194, 211, 203, 266, 272, 324, 360, 361, 431, 361, 382, 410, 407, 444, 440, 407, 420, 406, 410, 318, 350, 272, 299, 377, 390, 277, 264, 188, 3]

# %% [markdown]
# # Get most influential songs for each topic

# %%
# Create (num_songs, num_topics) array of influence scores
song_topic_inf_matrix = []

for time_idx in range(len(dim_model.time_slices)):    
    for song_idx in range(dim_model.time_slices[time_idx]):
        song_inf_by_topic = [None] * dim_model.num_topics

        for topic_idx in range(dim_model.num_topics):
            song_inf_by_topic[topic_idx] = dim_model.influences_time[time_idx][song_idx][topic_idx]
        
        song_topic_inf_matrix.append(song_inf_by_topic)

# %%
# Get the indices of the most influential songs per topic
most_inf_idx = np.array(song_topic_inf_matrix).argmax(axis=0)

for topic_no, artist_idx in enumerate(most_inf_idx):
    print "Topic:", topic_no
    # Lookup artist name
    print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
    # Lookup name of sample
    print os.listdir(bow_path_by_artist[artist_idx][1])[0]
    
    print
# Out:
# Topic: 0
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
#
# Topic: 1
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
#
# Topic: 2
# Big Jaz
# 0_Jigga WhatFaint.npy
#
# Topic: 3
# Big Jaz
# 0_Jigga WhatFaint.npy
#
# Topic: 4
# Sioux Falls
# 0_CopyPaste.npy

# %% [markdown]
# # Get most influential songs per topic per epoch

# %%
song_topic_inf_by_year = []
song_topic_inf_matrix_copy = copy(song_topic_inf_matrix)

# Slice song-topic matrix into list of submatrices keyed by time slice
for time_idx, num_in_slice in enumerate(dim_model.time_slices):
    song_topic_inf_by_year.append(song_topic_inf_matrix_copy[:num_in_slice])
    del song_topic_inf_matrix_copy[:num_in_slice]

# %%
for idx, song_topic_matrix in enumerate(song_topic_inf_by_year):
    print time_slice_dict[idx], ':', time_seq[idx], 'songs'
    print "==============================="

    # Get the indices of the most influential songs per topic
    # Note: Need to adjust indexing since index resets to 0 for each new year
    most_inf_idx = np.array(song_topic_matrix).argmax(axis=0) + sum(dim_model.time_slices[:idx])

    for topic_no, artist_idx in enumerate(most_inf_idx):
        print "Topic:", topic_no
        # Lookup artist name
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
        # Lookup name of sample
        print os.listdir(bow_path_by_artist[artist_idx][1])[0]
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['main_genre'].iloc[0]
        print
# Out:
# 1912 : 1 songs
# ===============================
# Topic: 0
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 1
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 2
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 3
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 4
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# 1916 : 1 songs
# ===============================
# Topic: 0
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 1
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 2
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 3
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 4
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# 1919 : 1 songs
# ===============================
# Topic: 0
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 1
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 2
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 3
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 4
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# 1921 : 1 songs
# ===============================
# Topic: 0
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 1
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 2
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 3
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 4
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# 1923 : 3 songs
# ===============================
# Topic: 0
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 1
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 2
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 3
# Arnaldo Antunes
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 4
# Stacey Pullen
# 0_Kevin Saunderson as E-Dancer Foundation [Original Mix].npy
# Electronic
#
# 1924 : 1 songs
# ===============================
# Topic: 0
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 1
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 2
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 3
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 4
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# 1926 : 1 songs
# ===============================
# Topic: 0
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 1
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 2
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 3
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 4
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# 1927 : 1 songs
# ===============================
# Topic: 0
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 1
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 2
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 3
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 4
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# 1928 : 5 songs
# ===============================
# Topic: 0
# Latin Playboys
# 0_Forever Night Shade Mary [From Show 78 "Night"].npy
# Pop/Rock
#
# Topic: 1
# Half Japanese
# 0_After Mendelssohn (137 Years)Paint It BlackArthur's ....npy
# Pop/Rock
#
# Topic: 2
# Orlando "Cachaito" Lopez
# 0_¿Y Tú Que Has Hecho?.npy
# Latin
#
# Topic: 3
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 4
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# 1929 : 3 songs
# ===============================
# Topic: 0
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 1
# Paul Di'Anno
# 0_Hot Legs.npy
# Pop/Rock
#
# Topic: 2
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 3
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 4
# Paul Di'Anno
# 0_Hot Legs.npy
# Pop/Rock
#
# 1930 : 2 songs
# ===============================
# Topic: 0
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 1
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 2
# Maurice Chevalier
# 0_I Love Paris.npy
# Vocal
#
# Topic: 3
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 4
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# 1931 : 2 songs
# ===============================
# Topic: 0
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 1
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 2
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 3
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 4
# Blonde Redhead
# 0_Futurism Vs. Passéism.npy
# Pop/Rock
#
# 1933 : 1 songs
# ===============================
# Topic: 0
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 1
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 2
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 3
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 4
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# 1935 : 2 songs
# ===============================
# Topic: 0
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 1
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 2
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 3
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 4
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# 1937 : 2 songs
# ===============================
# Topic: 0
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 1
# Anthony Coleman
# 0_The Ballad of Chernobyl.npy
# Avant-Garde
#
# Topic: 2
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 3
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 4
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# 1938 : 1 songs
# ===============================
# Topic: 0
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 1
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 2
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 3
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 4
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# 1939 : 1 songs
# ===============================
# Topic: 0
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 1
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 2
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 3
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 4
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# 1940 : 2 songs
# ===============================
# Topic: 0
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 1
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 2
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 3
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 4
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# 1941 : 2 songs
# ===============================
# Topic: 0
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 1
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 2
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 3
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 4
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# 1942 : 5 songs
# ===============================
# Topic: 0
# Papoose
# 0_Touch It [RemixFeaturing Mary J. Blige, Rah Digga, Missy Elliot, Lloyd Banks, Papoose & DMX].npy
# Rap
#
# Topic: 1
# Electrik Red
# 0_So Good.npy
# R&B;
#
# Topic: 2
# Papoose
# 0_Touch It [RemixFeaturing Mary J. Blige, Rah Digga, Missy Elliot, Lloyd Banks, Papoose & DMX].npy
# Rap
#
# Topic: 3
# The Barrett Sisters
# 0_I Shall Wear a Crown.npy
# Religious
#
# Topic: 4
# Colin Blunstone
# 0_London's Brilliant ParadeCaroline, Goodbye.npy
# Pop/Rock
#
# 1943 : 2 songs
# ===============================
# Topic: 0
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 1
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 2
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 3
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 4
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# 1944 : 2 songs
# ===============================
# Topic: 0
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 1
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 2
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 3
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 4
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# 1945 : 7 songs
# ===============================
# Topic: 0
# The Exploding Hearts
# 0_I'm a Pretender.npy
# Pop/Rock
#
# Topic: 1
# Kenny G
# 0_All the WayOne for My Baby (And One More for the Road).npy
# Jazz
#
# Topic: 2
# Radio Caroline
# 0_Freewheelin'.npy
# International
#
# Topic: 3
# Paul Carrack
# 0_Crying Won't Help You.npy
# Pop/Rock
#
# Topic: 4
# The Exploding Hearts
# 0_I'm a Pretender.npy
# Pop/Rock
#
# 1946 : 2 songs
# ===============================
# Topic: 0
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 1
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 2
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 3
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 4
# Token Entry
# 0_Lucky Seven.npy
# Pop/Rock
#
# 1947 : 5 songs
# ===============================
# Topic: 0
# 2 Live Jews
# 0_The Hustle (Parody: The Herschel).npy
# Comedy/Spoken
#
# Topic: 1
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 2
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 3
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 4
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# 1948 : 5 songs
# ===============================
# Topic: 0
# Zurdok
# 0_Estático.npy
# Latin
#
# Topic: 1
# Tom Jobim
# 0_Águas De Março.npy
# Latin
#
# Topic: 2
# Tom Jobim
# 0_Águas De Março.npy
# Latin
#
# Topic: 3
# Billy Mitchell
# 0_Long Notes Blue (Here Is Cecco Beppe).npy
# Jazz
#
# Topic: 4
# Billy Mitchell
# 0_Long Notes Blue (Here Is Cecco Beppe).npy
# Jazz
#
# 1949 : 5 songs
# ===============================
# Topic: 0
# E.G. Kight
# 0_A Woman Can Tell.npy
# Blues
#
# Topic: 1
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 2
# Eric Wood
# 0_Opus to Ecstasy.npy
# Folk
#
# Topic: 3
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 4
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# 1950 : 6 songs
# ===============================
# Topic: 0
# U-Roy
# 0_Wear You to the Ball.npy
# Reggae
#
# Topic: 1
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 2
# Streetwize
# 0_Don't Say Goodnight (It's Time for Love).npy
# Jazz
#
# Topic: 3
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 4
# King Leg
# 0_Comfy ChairA Dream That Never Ends.npy
# Pop/Rock
#
# 1951 : 4 songs
# ===============================
# Topic: 0
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 1
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 2
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 3
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 4
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# 1952 : 6 songs
# ===============================
# Topic: 0
# I Am the World Trade Center
# 0_Shoot You Down.npy
# Pop/Rock
#
# Topic: 1
# Javen
# 0_Wipe Away My Tears.npy
# R&B;
#
# Topic: 2
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 3
# Tommy Smith
# 0_Independency, Pt. 1.npy
# Jazz
#
# Topic: 4
# I Am the World Trade Center
# 0_Shoot You Down.npy
# Pop/Rock
#
# 1953 : 11 songs
# ===============================
# Topic: 0
# Luciano
# 0_Neighbourhood Watch.npy
# Reggae
#
# Topic: 1
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 2
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 3
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 4
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# 1954 : 15 songs
# ===============================
# Topic: 0
# Louis Armstrong
# 0_I'm Just a Lucky So and So.npy
# Jazz
#
# Topic: 1
# Kurupt
# 0_Dogg Pound Gangstaville.npy
# Rap
#
# Topic: 2
# Louis Armstrong
# 0_I'm Just a Lucky So and So.npy
# Jazz
#
# Topic: 3
# Winans Phase 2
# 0_This Train.npy
# Religious
#
# Topic: 4
# Kurupt
# 0_Dogg Pound Gangstaville.npy
# Rap
#
# 1955 : 30 songs
# ===============================
# Topic: 0
# JT the Bigga Figga
# 0_F*****' Is Good for U.npy
# Rap
#
# Topic: 1
# Salif Keita
# 0_Burned with Desire.npy
# International
#
# Topic: 2
# JT the Bigga Figga
# 0_F*****' Is Good for U.npy
# Rap
#
# Topic: 3
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 4
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# 1956 : 42 songs
# ===============================
# Topic: 0
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 1
# Christafari
# 0_Never Let You Go.npy
# Religious
#
# Topic: 2
# Dopplereffekt
# 0_Old Skool Cut Up: Rhythm Trax (House Party Style) SterilizationS ....npy
# Electronic
#
# Topic: 3
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 4
# Steve Cole
# 0_Chopsticks.npy
# Jazz
#
# 1957 : 37 songs
# ===============================
# Topic: 0
# The BusBoys
# 0_Right Place, Wrong Time.npy
# Pop/Rock
#
# Topic: 1
# Elaine Brown
# 0_Prove Your Love to Me.npy
# Pop/Rock
#
# Topic: 2
# Paulinho da Viola
# 0_Não Tenho Lágrimas.npy
# Latin
#
# Topic: 3
# Paulinho da Viola
# 0_Não Tenho Lágrimas.npy
# Latin
#
# Topic: 4
# Elaine Brown
# 0_Prove Your Love to Me.npy
# Pop/Rock
#
# 1958 : 64 songs
# ===============================
# Topic: 0
# Garnett Silk
# 0_Love Is the Answer.npy
# Reggae
#
# Topic: 1
# Jordan Rager
# 0_Southern Boy.npy
# Country
#
# Topic: 2
# Fred Frith
# 0_The Fourth Mind.npy
# Avant-Garde
#
# Topic: 3
# Bomb the Bass
# 0_Bug Powder DustPump Me UpHow HighPoisonBeen Caught StealingI ....npy
# Electronic
#
# Topic: 4
# Jordan Rager
# 0_Southern Boy.npy
# Country
#
# 1959 : 44 songs
# ===============================
# Topic: 0
# Moonshine Bandits
# 0_Mud Digger Mega Remix.npy
# Rap
#
# Topic: 1
# The Intruders
# 0_Just the Lonely Talkin' Again.npy
# R&B;
#
# Topic: 2
# Dabrye
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Rap
#
# Topic: 3
# Dabrye
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Rap
#
# Topic: 4
# Broken Teeth
# 0_UndertakerTrippin Over a Bone.npy
# Pop/Rock
#
# 1960 : 44 songs
# ===============================
# Topic: 0
# The Royal Guardsmen
# 0_Imperial Bedroom.npy
# Pop/Rock
#
# Topic: 1
# The Christianaires
# 0_Stand Up.npy
# Religious
#
# Topic: 2
# Bobby Hackett
# 0_Body & Soul.npy
# Jazz
#
# Topic: 3
# Oliver Morgan
# 0_Trick Bag.npy
# R&B;
#
# Topic: 4
# The Christianaires
# 0_Stand Up.npy
# Religious
#
# 1961 : 42 songs
# ===============================
# Topic: 0
# Lonesome Sundown
# 0_My Home Is a Prison.npy
# Blues
#
# Topic: 1
# Jordan Fisher
# 0_Gotta Be Me.npy
# Pop/Rock
#
# Topic: 2
# Pinetop Perkins
# 0_Pinetop's Boogie Woogie.npy
# Blues
#
# Topic: 3
# Pepe Aguilar
# 0_Me Vas a Extrañar.npy
# Latin
#
# Topic: 4
# Jordan Fisher
# 0_Gotta Be Me.npy
# Pop/Rock
#
# 1962 : 52 songs
# ===============================
# Topic: 0
# Toño Rosario
# 0_Amigo Mio.npy
# Latin
#
# Topic: 1
# Toño Rosario
# 0_Amigo Mio.npy
# Latin
#
# Topic: 2
# Johnny Osbourne
# 0_No Ice Cream Sound.npy
# Reggae
#
# Topic: 3
# Railroad Jerk
# 0_Good News.npy
# Pop/Rock
#
# Topic: 4
# Railroad Jerk
# 0_Good News.npy
# Pop/Rock
#
# 1963 : 62 songs
# ===============================
# Topic: 0
# Pete Brown
# 0_Moonglow.npy
# Jazz
#
# Topic: 1
# Melissa Manchester
# 0_You Should Hear How They Talk About You.npy
# Pop/Rock
#
# Topic: 2
# Chuck Wayne
# 0_Conception.npy
# Jazz
#
# Topic: 3
# Chuck Wayne
# 0_Conception.npy
# Jazz
#
# Topic: 4
# Charles Aznavour
# 0_J'Aime Paris au Mois de Mai.npy
# Vocal
#
# 1964 : 49 songs
# ===============================
# Topic: 0
# Red Meat
# 0_High Maintenance Babe.npy
# Country
#
# Topic: 1
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# Topic: 2
# Cachao
# 0_Let Her Go.npy
# Latin
#
# Topic: 3
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# Topic: 4
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# 1965 : 84 songs
# ===============================
# Topic: 0
# Tupac Shakur
# 0_BiggieTupac Live Freestyle.npy
# Rap
#
# Topic: 1
# MC Paul Barman
# 0_Salvation Barny.npy
# Rap
#
# Topic: 2
# George Tandy, Jr.
# 0_Jaded.npy
# R&B;
#
# Topic: 3
# Cold Blood
# 0_Understanding.npy
# Pop/Rock
#
# Topic: 4
# Cold Blood
# 0_Understanding.npy
# Pop/Rock
#
# 1966 : 73 songs
# ===============================
# Topic: 0
# The Glimmers
# 0_En Real T Jukkas.npy
# Electronic
#
# Topic: 1
# Ms. Jody
# 0_Take Me.npy
# R&B;
#
# Topic: 2
# Kali Uchis
# 0_Only Girl.npy
# Pop/Rock
#
# Topic: 3
# Cabas
# 0_Mi Bombón.npy
# Latin
#
# Topic: 4
# Cabas
# 0_Mi Bombón.npy
# Latin
#
# 1967 : 100 songs
# ===============================
# Topic: 0
# Eddie Kirkland
# 0_That's All Right.npy
# Blues
#
# Topic: 1
# Morgan Heritage
# 0_Down by the River.npy
# Reggae
#
# Topic: 2
# The Charioteers
# 0_I've Got a Home in That Rock.npy
# Religious
#
# Topic: 3
# Tex Williams
# 0_Smoke! Smoke! Smoke! (That Cigarette).npy
# Country
#
# Topic: 4
# The Roosevelts
# 0_Don't Wanna Let You Go.npy
# Pop/Rock
#
# 1968 : 113 songs
# ===============================
# Topic: 0
# Nappy Brown
# 0_Don't Be Angry.npy
# Blues
#
# Topic: 1
# Sonny Clark
# 0_Love for Sale.npy
# Jazz
#
# Topic: 2
# Léo Ferré
# 0_Paris Canaille.npy
# Vocal
#
# Topic: 3
# Hank Thompson
# 0_Humpty Dumpty Heart.npy
# Country
#
# Topic: 4
# The Robins
# 0_Smokey Joe's Cafe.npy
# R&B;
#
# 1969 : 117 songs
# ===============================
# Topic: 0
# Warren Smith
# 0_Rock 'N' Roll Ruby.npy
# Pop/Rock
#
# Topic: 1
# Cutty Cutshall
# 0_Someday You'll Be Sorry.npy
# Jazz
#
# Topic: 2
# Screamin' Jay Hawkins
# 0_Little Demon.npy
# R&B;
#
# Topic: 3
# Cutty Cutshall
# 0_Someday You'll Be Sorry.npy
# Jazz
#
# Topic: 4
# Screamin' Jay Hawkins
# 0_Little Demon.npy
# R&B;
#
# 1970 : 112 songs
# ===============================
# Topic: 0
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 1
# Sam Cooke
# 0_Chain Gang.npy
# R&B;
#
# Topic: 2
# Duane Eddy
# 0_Shazam!.npy
# Pop/Rock
#
# Topic: 3
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 4
# Fabian
# 0_Tiger.npy
# Pop/Rock
#
# 1971 : 94 songs
# ===============================
# Topic: 0
# Gary "U.S." Bonds
# 0_Quarter to Three.npy
# Pop/Rock
#
# Topic: 1
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# Topic: 2
# Bernard Cribbins
# 0_Right Said Fred.npy
# Children's
#
# Topic: 3
# Ben E. King
# 0_Spanish Harlem.npy
# R&B;
#
# Topic: 4
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# 1972 : 135 songs
# ===============================
# Topic: 0
# Sandie Shaw
# 0_(There's) Always Something There to Remind Me.npy
# Pop/Rock
#
# Topic: 1
# Jerry Butler
# 0_For Your Precious Love.npy
# R&B;
#
# Topic: 2
# Walter Jackson
# 0_It's All Over.npy
# R&B;
#
# Topic: 3
# The Searchers
# 0_Take Me for What I'm Worth.npy
# Pop/Rock
#
# Topic: 4
# The Angels
# 0_My Boyfriend's Back.npy
# Pop/Rock
#
# 1973 : 103 songs
# ===============================
# Topic: 0
# The Statler Brothers
# 0_Flowers on the Wall.npy
# Country
#
# Topic: 1
# The Gentrys
# 0_Keep on Dancing.npy
# Pop/Rock
#
# Topic: 2
# Peppermint Harris
# 0_Bad Bad Whiskey.npy
# Blues
#
# Topic: 3
# Jim Kweskin
# 0_Blues My Naughty Sweetie Gives to Me.npy
# Folk
#
# Topic: 4
# Owen Gray
# 0_Can I Get a Witness.npy
# Reggae
#
# 1974 : 133 songs
# ===============================
# Topic: 0
# Herman's Hermits
# 0_There's a Kind of Hush (All Over the World).npy
# Pop/Rock
#
# Topic: 1
# Tammi Terrell
# 0_If I Could Build My Whole World Around You.npy
# R&B;
#
# Topic: 2
# Tammi Terrell
# 0_If I Could Build My Whole World Around You.npy
# R&B;
#
# Topic: 3
# O.V. Wright
# 0_Eight Men, Four Women.npy
# R&B;
#
# Topic: 4
# Chad & Jeremy
# 0_A Summer Song.npy
# Pop/Rock
#
# 1975 : 126 songs
# ===============================
# Topic: 0
# Arthur Brown
# 0_Fire.npy
# Pop/Rock
#
# Topic: 1
# Buzzy Linhart
# 0_Yellow Cab.npy
# Folk
#
# Topic: 2
# Betty Harris
# 0_Ride Your Pony.npy
# R&B;
#
# Topic: 3
# Bobbie Gentry
# 0_All I Have to Do Is Dream.npy
# Country
#
# Topic: 4
# Clancy Eccles
# 0_C.N. Express.npy
# Reggae
#
# 1976 : 131 songs
# ===============================
# Topic: 0
# El Chicano
# 0_Viva Tirado.npy
# Pop/Rock
#
# Topic: 1
# Sam & Dave
# 0_Said I Wasn't Gonna Tell Nobody.npy
# R&B;
#
# Topic: 2
# J.T. Brown
# 0_I Can't Hold Out.npy
# Blues
#
# Topic: 3
# Sam & Dave
# 0_Said I Wasn't Gonna Tell Nobody.npy
# R&B;
#
# Topic: 4
# Sam & Dave
# 0_Said I Wasn't Gonna Tell Nobody.npy
# R&B;
#
# 1977 : 112 songs
# ===============================
# Topic: 0
# Los del Rio
# 0_La Canto.npy
# Latin
#
# Topic: 1
# Michael Nesmith
# 0_Joanne.npy
# Pop/Rock
#
# Topic: 2
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 3
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 4
# The Jimi Hendrix Experience
# 0_Manic Depression.npy
# Pop/Rock
#
# 1978 : 141 songs
# ===============================
# Topic: 0
# Guru Guru
# 0_Oxymoron.npy
# Pop/Rock
#
# Topic: 1
# G. Love
# 0_Rainbow.npy
# Pop/Rock
#
# Topic: 2
# Guru Guru
# 0_Oxymoron.npy
# Pop/Rock
#
# Topic: 3
# Thom Bell
# 0_You'll Never Get to Heaven (If You Break My Heart).npy
# R&B;
#
# Topic: 4
# G. Love
# 0_Rainbow.npy
# Pop/Rock
#
# 1979 : 152 songs
# ===============================
# Topic: 0
# Golden Earring
# 0_Radar Love.npy
# Pop/Rock
#
# Topic: 1
# Highway 101
# 0_Young Country.npy
# Country
#
# Topic: 2
# Three Dog Night
# 0_Joy to the World.npy
# Pop/Rock
#
# Topic: 3
# The Heptones
# 0_Book of Rules.npy
# Reggae
#
# Topic: 4
# Highway 101
# 0_Young Country.npy
# Country
#
# 1980 : 167 songs
# ===============================
# Topic: 0
# Shirley Caesar
# 0_No Charge.npy
# Religious
#
# Topic: 1
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 2
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 3
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 4
# Be Bop Deluxe
# 0_Ships in the Night.npy
# Pop/Rock
#
# 1981 : 155 songs
# ===============================
# Topic: 0
# Bob Marley
# 0_Keep on Movin'.npy
# Reggae
#
# Topic: 1
# Cameo
# 0_In the Night.npy
# R&B;
#
# Topic: 2
# Cameo
# 0_In the Night.npy
# R&B;
#
# Topic: 3
# Sherbet
# 0_Summer Love.npy
# Pop/Rock
#
# Topic: 4
# Donna Fargo
# 0_Jingle Bells.npy
# Country
#
# 1982 : 156 songs
# ===============================
# Topic: 0
# Johnny Paycheck
# 0_Maybellene.npy
# Country
#
# Topic: 1
# Sun
# 0_Sun Is Here.npy
# R&B;
#
# Topic: 2
# Stuff
# 0_Signed, Sealed, Delivered I'm Yours.npy
# R&B;
#
# Topic: 3
# Riders in the Sky
# 0_Back in the Saddle Again.npy
# Country
#
# Topic: 4
# Lit
# 0_Borrowed Time.npy
# Pop/Rock
#
# 1983 : 160 songs
# ===============================
# Topic: 0
# Stevie Wonder
# 0_One Little Christmas Tree.npy
# R&B;
#
# Topic: 1
# Chris LeDoux
# 0_Copenhagen.npy
# Country
#
# Topic: 2
# Paul Williams
# 0_Rainbow Connection.npy
# Pop/Rock
#
# Topic: 3
# Rickie Lee Jones
# 0_Chuck E's in Love.npy
# Pop/Rock
#
# Topic: 4
# Chris LeDoux
# 0_Copenhagen.npy
# Country
#
# 1984 : 141 songs
# ===============================
# Topic: 0
# Killing Joke
# 0_Change.npy
# Pop/Rock
#
# Topic: 1
# Ian McLagan
# 0_Breathe on Me.npy
# Pop/Rock
#
# Topic: 2
# Louie Ramirez
# 0_Los Bravos.npy
# Latin
#
# Topic: 3
# Gary Moore
# 0_Parisienne Walkways.npy
# Pop/Rock
#
# Topic: 4
# The Tourists
# 0_I Only Want to Be with You.npy
# Pop/Rock
#
# 1985 : 164 songs
# ===============================
# Topic: 0
# Creedence Clearwater Revival
# 0_Someday Never Comes.npy
# Pop/Rock
#
# Topic: 1
# Urban Verbs
# 0_Acceleration.npy
# Pop/Rock
#
# Topic: 2
# Sky
# 0_Hotta.npy
# Pop/Rock
#
# Topic: 3
# Buddy Miles
# 0_It's Too Bad.npy
# Pop/Rock
#
# Topic: 4
# Urban Verbs
# 0_Acceleration.npy
# Pop/Rock
#
# 1986 : 171 songs
# ===============================
# Topic: 0
# The Jonzun Crew
# 0_Pack Jam (Look Out for the OVC).npy
# R&B;
#
# Topic: 1
# Plush
# 0_Free and Easy.npy
# R&B;
#
# Topic: 2
# Bill Withers
# 0_Just the Two of Us.npy
# R&B;
#
# Topic: 3
# Bill Withers
# 0_Just the Two of Us.npy
# R&B;
#
# Topic: 4
# The Jonzun Crew
# 0_Pack Jam (Look Out for the OVC).npy
# R&B;
#
# 1987 : 172 songs
# ===============================
# Topic: 0
# Touchdown
# 0_Ease Your Mind.npy
# Electronic
#
# Topic: 1
# Rufus
# 0_Ain't Nobody.npy
# R&B;
#
# Topic: 2
# John Mellencamp
# 0_Pink Houses.npy
# Pop/Rock
#
# Topic: 3
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 4
# Night Ranger
# 0_Don't Tell Me You Love Me.npy
# Pop/Rock
#
# 1988 : 182 songs
# ===============================
# Topic: 0
# Scritti Politti
# 0_Wood Beez (Pray Like Aretha Franklin).npy
# Pop/Rock
#
# Topic: 1
# Zero Hour
# 0_Dark Side.npy
# Pop/Rock
#
# Topic: 2
# The Art of Noise
# 0_Moments in Love.npy
# Pop/Rock
#
# Topic: 3
# K. Michelle
# 0_Ride Out.npy
# R&B;
#
# Topic: 4
# Ambitious Lovers
# 0_Let's Be Adult.npy
# Pop/Rock
#
# 1989 : 175 songs
# ===============================
# Topic: 0
# Carlene Davis
# 0_Bits and Pieces.npy
# Reggae
#
# Topic: 1
# Elvis Costello & the Attractions
# 0_Pump It Up.npy
# Pop/Rock
#
# Topic: 2
# Marilyn Monroe
# 0_Down in the Meadow.npy
# Vocal
#
# Topic: 3
# Han Bennink
# 0_Change of Season.npy
# Jazz
#
# Topic: 4
# The Fuzztones
# 0_She's Wicked.npy
# Pop/Rock
#
# 1990 : 194 songs
# ===============================
# Topic: 0
# The Controllers
# 0_Got a Thang.npy
# R&B;
#
# Topic: 1
# P.F. Sloan
# 0_Sins of a Family.npy
# Pop/Rock
#
# Topic: 2
# The Controllers
# 0_Got a Thang.npy
# R&B;
#
# Topic: 3
# David + David
# 0_Welcome to the Boomtown.npy
# Pop/Rock
#
# Topic: 4
# Larry Graham
# 0_If You Need My Love Tonight.npy
# R&B;
#
# 1991 : 211 songs
# ===============================
# Topic: 0
# Meli'sa Morgan
# 0_Love Changes.npy
# R&B;
#
# Topic: 1
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 2
# Gene Ammons
# 0_My Romance.npy
# Jazz
#
# Topic: 3
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 4
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# 1992 : 203 songs
# ===============================
# Topic: 0
# Junkyard
# 0_Hollywood.npy
# Pop/Rock
#
# Topic: 1
# Dead Milkmen
# 0_Smokin' Banana Peels.npy
# Pop/Rock
#
# Topic: 2
# Bobby McFerrin
# 0_Don't Worry Be Happy.npy
# Vocal
#
# Topic: 3
# Bobby McFerrin
# 0_Don't Worry Be Happy.npy
# Vocal
#
# Topic: 4
# Rick Springfield
# 0_Love Somebody.npy
# Pop/Rock
#
# 1993 : 266 songs
# ===============================
# Topic: 0
# Swampwater
# 0_Freeborn Man.npy
# Pop/Rock
#
# Topic: 1
# Dave Hole
# 0_Short Fuse Blues.npy
# Blues
#
# Topic: 2
# Public Enemy
# 0_911 Is a Joke.npy
# Rap
#
# Topic: 3
# Dave Hole
# 0_Short Fuse Blues.npy
# Blues
#
# Topic: 4
# Ricardo Montaner
# 0_Cima del Cielo.npy
# Latin
#
# 1994 : 272 songs
# ===============================
# Topic: 0
# Roy Wood
# 0_I Heard It Through the Grapevine.npy
# Pop/Rock
#
# Topic: 1
# 2nd II None
# 0_Skanless.npy
# Rap
#
# Topic: 2
# Slowdive
# 0_Catch the Breeze.npy
# Pop/Rock
#
# Topic: 3
# Will Lee
# 0_Spherical.npy
# Jazz
#
# Topic: 4
# London
# 0_Ha Ha.npy
# Pop/Rock
#
# 1995 : 324 songs
# ===============================
# Topic: 0
# Das EFX
# 0_Check Yo Self.npy
# Rap
#
# Topic: 1
# Stella
# 0_Friends.npy
# R&B;
#
# Topic: 2
# Stella
# 0_Friends.npy
# R&B;
#
# Topic: 3
# Paul Buskirk
# 0_I Will Wait for You.npy
# Pop/Rock
#
# Topic: 4
# Vibro Champs
# 0_Martian Trip.npy
# Pop/Rock
#
# 1996 : 360 songs
# ===============================
# Topic: 0
# Thee Headcoatees
# 0_Gotta Get The First Plane Home.npy
# Pop/Rock
#
# Topic: 1
# Ashley Cleveland
# 0_Oh How the Years Go By.npy
# Religious
#
# Topic: 2
# Tom Bee
# 0_Teach Your Children.npy
# Folk
#
# Topic: 3
# Jon Secada
# 0_The Best Is Yet to Come.npy
# R&B;
#
# Topic: 4
# Curtis Salgado
# 0_I'll Be Back.npy
# Blues
#
# 1997 : 361 songs
# ===============================
# Topic: 0
# Big Boy
# 0_The Hustle.npy
# Rap
#
# Topic: 1
# L.V.
# 0_Gangsta's Paradise.npy
# Rap
#
# Topic: 2
# Zap Pow
# 0_Small Axe.npy
# Reggae
#
# Topic: 3
# Israel Vibration
# 0_The Same Song.npy
# Reggae
#
# Topic: 4
# The Four Tops
# 0_Silent Night.npy
# R&B;
#
# 1998 : 431 songs
# ===============================
# Topic: 0
# 5th Ward Boyz
# 0_I Know.npy
# Rap
#
# Topic: 1
# Yves Deruyter
# 0_The Rebel.npy
# Electronic
#
# Topic: 2
# Zhané
# 0_It's a Party.npy
# R&B;
#
# Topic: 3
# Scientist
# 0_Miss Know It All.npy
# Reggae
#
# Topic: 4
# Les Savy Fav
# 0_Rodeo.npy
# Pop/Rock
#
# 1999 : 361 songs
# ===============================
# Topic: 0
# King Radio
# 0_DC-10.npy
# International
#
# Topic: 1
# Hepcat
# 0_I Can't Wait.npy
# Reggae
#
# Topic: 2
# ATB
# 0_9 P.M. (Till I Come).npy
# Electronic
#
# Topic: 3
# Chris Knight
# 0_Something Changed.npy
# Country
#
# Topic: 4
# Firewater
# 0_Another Perfect Catastrophe.npy
# Pop/Rock
#
# 2000 : 382 songs
# ===============================
# Topic: 0
# Hate Dept.
# 0_Effigy.npy
# Pop/Rock
#
# Topic: 1
# Sacrifice Isaac
# 0_1000 Years Worth.npy
# Pop/Rock
#
# Topic: 2
# Sacrifice Isaac
# 0_1000 Years Worth.npy
# Pop/Rock
#
# Topic: 3
# Rahsaan Patterson
# 0_Tears on My Pillow.npy
# R&B;
#
# Topic: 4
# Sacrifice Isaac
# 0_1000 Years Worth.npy
# Pop/Rock
#
# 2001 : 410 songs
# ===============================
# Topic: 0
# Catch 22
# 0_Thunderkiss '65.npy
# Pop/Rock
#
# Topic: 1
# Front Line Assembly
# 0_New Year's Day.npy
# Pop/Rock
#
# Topic: 2
# Tina Turner
# 0_Hot Legs.npy
# R&B;
#
# Topic: 3
# Tina Turner
# 0_Hot Legs.npy
# R&B;
#
# Topic: 4
# Front Line Assembly
# 0_New Year's Day.npy
# Pop/Rock
#
# 2002 : 407 songs
# ===============================
# Topic: 0
# Groove Collective
# 0_Stargazer.npy
# R&B;
#
# Topic: 1
# Esham
# 0_All Night Everyday.npy
# Rap
#
# Topic: 2
# Mount Florida
# 0_Don't Do Dada.npy
# Electronic
#
# Topic: 3
# Groove Collective
# 0_Stargazer.npy
# R&B;
#
# Topic: 4
# Si*Sé
# 0_The Rain (Where Do I Begin?).npy
# Electronic
#
# 2003 : 444 songs
# ===============================
# Topic: 0
# RZA
# 0_Wu-Gambinos.npy
# Rap
#
# Topic: 1
# Paul Gilbert
# 0_Let the Computer Decide.npy
# Pop/Rock
#
# Topic: 2
# Kit Clayton
# 0_0-1.npy
# Electronic
#
# Topic: 3
# Van Hunt
# 0_Something to Believe In.npy
# R&B;
#
# Topic: 4
# Paul Gilbert
# 0_Let the Computer Decide.npy
# Pop/Rock
#
# 2004 : 440 songs
# ===============================
# Topic: 0
# The Dirtbombs
# 0_I'm Through With White Girls.npy
# Pop/Rock
#
# Topic: 1
# Roots Manuva
# 0_Gdmfsob.npy
# Rap
#
# Topic: 2
# Todd Edwards
# 0_Face to Face.npy
# Electronic
#
# Topic: 3
# Roots Manuva
# 0_Gdmfsob.npy
# Rap
#
# Topic: 4
# Sense Field
# 0_On Your Own.npy
# Pop/Rock
#
# 2005 : 407 songs
# ===============================
# Topic: 0
# Mindflayer
# 0_1999 Animals Revenge.npy
# Pop/Rock
#
# Topic: 1
# Solvent
# 0_Think Like Us.npy
# Electronic
#
# Topic: 2
# Money Mark
# 0_Butternut.npy
# Pop/Rock
#
# Topic: 3
# The Subdudes
# 0_The Rain.npy
# Pop/Rock
#
# Topic: 4
# The Subdudes
# 0_The Rain.npy
# Pop/Rock
#
# 2006 : 420 songs
# ===============================
# Topic: 0
# Indigo Girls
# 0_Rock and Roll Heaven's Gate.npy
# Pop/Rock
#
# Topic: 1
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 2
# Black Dice
# 0_Smiling Off.npy
# Pop/Rock
#
# Topic: 3
# Ernie Halter
# 0_Played.npy
# Pop/Rock
#
# Topic: 4
# Cobra Verde
# 0_Play With Fire.npy
# Pop/Rock
#
# 2007 : 406 songs
# ===============================
# Topic: 0
# Gift of Gab
# 0_All Night (Intro)Watch Out!.npy
# Rap
#
# Topic: 1
# Field Mob
# 0_So What.npy
# Rap
#
# Topic: 2
# Jose Conde y Ola Fresca
# 0_Pititi y Titi.npy
# International
#
# Topic: 3
# Waajeed
# 0_Knives Out.npy
# Rap
#
# Topic: 4
# Woods of Ypres
# 0_Trillium: The Third of Three Winters 2004-2007 [Instrumental].npy
# Pop/Rock
#
# 2008 : 410 songs
# ===============================
# Topic: 0
# Gia Farrell
# 0_Hit Me Up.npy
# Pop/Rock
#
# Topic: 1
# Ray J
# 0_We Are Family.npy
# R&B;
#
# Topic: 2
# Fabio Fonseca
# 0_Samba da Copa.npy
# Jazz
#
# Topic: 3
# Vic Juris
# 0_Black Satin.npy
# Jazz
#
# Topic: 4
# Katatonia
# 0_July.npy
# Pop/Rock
#
# 2009 : 318 songs
# ===============================
# Topic: 0
# Mayo Thompson
# 0_The Lesson.npy
# Pop/Rock
#
# Topic: 1
# Robert Ward
# 0_So Tired of Wandering.npy
# Blues
#
# Topic: 2
# Michna
# 0_Redline Flights.npy
# Electronic
#
# Topic: 3
# Kodomo
# 0_Concept 13.npy
# Electronic
#
# Topic: 4
# Government Issue
# 0_Blending In.npy
# Pop/Rock
#
# 2010 : 350 songs
# ===============================
# Topic: 0
# Solex
# 0_The Uppercut.npy
# Electronic
#
# Topic: 1
# Nick Jonas & the Administration
# 0_Who I Am.npy
# Pop/Rock
#
# Topic: 2
# Asher Roth
# 0_Fuck the Money.npy
# Rap
#
# Topic: 3
# Playdoe
# 0_Game.npy
# Rap
#
# Topic: 4
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# 2011 : 272 songs
# ===============================
# Topic: 0
# Teedra Moses
# 0_Self Made.npy
# R&B;
#
# Topic: 1
# Los Tigres del Norte
# 0_Jefe De Jefes.npy
# Latin
#
# Topic: 2
# Michael Giacchino
# 0_Super 8 Suite.npy
# Stage & Screen
#
# Topic: 3
# Los Tigres del Norte
# 0_Jefe De Jefes.npy
# Latin
#
# Topic: 4
# Brand New
# 0_Soco Amaretto Lime.npy
# Pop/Rock
#
# 2012 : 299 songs
# ===============================
# Topic: 0
# Suburban Legends
# 0_Powerful Game.npy
# Pop/Rock
#
# Topic: 1
# The Moonglows
# 0_Seven Day Fool.npy
# R&B;
#
# Topic: 2
# Jamey Johnson
# 0_Don't You Ever Get Tired of Hurting Me.npy
# Country
#
# Topic: 3
# Jamey Johnson
# 0_Don't You Ever Get Tired of Hurting Me.npy
# Country
#
# Topic: 4
# Two Door Cinema Club
# 0_Something Good Can Work.npy
# Pop/Rock
#
# 2013 : 377 songs
# ===============================
# Topic: 0
# Sheléa
# 0_Let It Go.npy
# R&B;
#
# Topic: 1
# Lorn
# 0_Chhurch.npy
# Electronic
#
# Topic: 2
# Rachael Sage
# 0_Invisible Light.npy
# Pop/Rock
#
# Topic: 3
# Liza Minnelli
# 0_I've Got the World on a String.npy
# Vocal
#
# Topic: 4
# Ha Ha Tonka
# 0_Lessons.npy
# Pop/Rock
#
# 2014 : 390 songs
# ===============================
# Topic: 0
# DJ Quik
# 0_Shine.npy
# Rap
#
# Topic: 1
# C-Kan
# 0_Culpame a Mi.npy
# Rap
#
# Topic: 2
# Booka Shade
# 0_Love Inc.npy
# Electronic
#
# Topic: 3
# Booka Shade
# 0_Love Inc.npy
# Electronic
#
# Topic: 4
# Periphery
# 0_Only if for a Night.npy
# Pop/Rock
#
# 2015 : 277 songs
# ===============================
# Topic: 0
# Long John Baldry
# 0_Bright Lights, Big City.npy
# Blues
#
# Topic: 1
# Meghan Trainor
# 0_All About That Bass [Radio Disney Version].npy
# Pop/Rock
#
# Topic: 2
# Ana Moura
# 0_Dream of Fire.npy
# International
#
# Topic: 3
# Elvis Perkins
# 0_Moon Woman, Pt. 2.npy
# Pop/Rock
#
# Topic: 4
# Joe Hertler & the Rainbow Seekers
# 0_King is Dead.npy
# Pop/Rock
#
# 2016 : 264 songs
# ===============================
# Topic: 0
# Boys Like Girls
# 0_The Great Escape.npy
# Pop/Rock
#
# Topic: 1
# James Supercave
# 0_Burn.npy
# Pop/Rock
#
# Topic: 2
# Eddie Bo
# 0_St. James Infirmary.npy
# R&B;
#
# Topic: 3
# Joshua Redman
# 0_Ornithology.npy
# Jazz
#
# Topic: 4
# The Dead Ships
# 0_Canyon.npy
# Pop/Rock
#
# 2017 : 188 songs
# ===============================
# Topic: 0
# Dan Hicks & His Hot Licks
# 0_Strike It While It's Hot.npy
# Pop/Rock
#
# Topic: 1
# Starrah
# 0_Imperfections.npy
# R&B;
#
# Topic: 2
# The Frightnrs
# 0_Nothing More to Say.npy
# Pop/Rock
#
# Topic: 3
# Terry Reid
# 0_Listen.npy
# Pop/Rock
#
# Topic: 4
# Esmé Patterson
# 0_Call It Heaven.npy
# Pop/Rock
#
# 2018 : 3 songs
# ===============================
# Topic: 0
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 1
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 2
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 3
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 4
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock

# %% [markdown]
# # Correlation with AllMusic Influence Graph Degree

# %%
# Calculate max DIM influence per artist
max_dim_influences = np.array(song_topic_inf_matrix).max(axis=1)

# Get list of artist outdegrees in same order
artist_ids_ordered = [t[0] for t in bow_path_by_artist]
outdegrees_ordered = []

for id in artist_ids_ordered:
    outdegrees_ordered.append(artists[artists['id'] == id]['outdegree'].iloc[0])

# %%
# Calculate correlation
spearmanr(max_dim_influences, outdegrees_ordered)
# Out:
# SpearmanrResult(correlation=0.050810378893831672, pvalue=4.0342621408735467e-09)

# %% [markdown]
# # TODO: Baseline

# %% [markdown]
# # TODO: Breakdown by Genre
