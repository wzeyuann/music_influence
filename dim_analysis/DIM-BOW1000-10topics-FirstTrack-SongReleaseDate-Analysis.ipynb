# %%
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import pandas as pd
import os
from copy import copy
from collections import OrderedDict
from scipy.stats import spearmanr
from tqdm import tqdm_notebook
import pickle

# %%
MODEL_PATH = '../models/dim_bow1000_10topics_firsttrack_songreleasedate'
BOW_DIR = '../data/features/bow_1000/'

# %%
# Load model
dim_model = DtmModel.load(MODEL_PATH)

# %%
# Load artist info
artists = pd.read_csv('../data/allmusic/artists_cleaned.csv')

# %%
# Load song info
songs = pd.read_csv('../data/artist_song_list_years_cleaned.csv')

# %%
# Load bow_path_by_artist
bow_path_by_artist = pickle.load(open('../models/bow500_path_by_artist.pk', 'rb'))

# %%
bow_path_by_artist_new = []

for (id, path, year) in bow_path_by_artist:
    bow_path_by_artist_new.append((id, BOW_DIR + path.split('/n/regal/rush_lab/xue/bow_500/')[1], year))

bow_path_by_artist = bow_path_by_artist_new

# %%
# # Add a column with a ".npy" extension
# songs['name_ext'] = songs['name_no_ext'].apply(lambda x: (x + '.npy')).str.decode('utf-8')

# # list of (artist_id, path, year) tuples
# bow_path_by_artist = []

# ids_in_songs = set(songs['artist_id'])

# for artist_id in tqdm_notebook(os.listdir(BOW_DIR)):
#     song_filename = os.listdir(BOW_DIR + artist_id)[0].decode('utf-8')
    
#     # Check if song year is missing or artist is missing from song df
#     if int(artist_id) in ids_in_songs and songs[songs['name_ext'] == song_filename]['year'].iloc[0] != 0:
#         # save (artist_id, path, year) tuple
#         bow_path_by_artist.append((int(artist_id), BOW_DIR + artist_id + '/', songs[songs['name_ext'] == song_filename]['year'].iloc[0]))

# print "Number of songs:", len(bow_path_by_artist)

# Order list by year
bow_path_by_artist.sort(key= lambda x: songs[songs['artist_id'] == x[0]]['year'].iloc[0])

# Create counter for number of songs for each year 
year_counter = {int(k) : 0 for k in np.unique(zip(*bow_path_by_artist)[2])}

for id, path, year in bow_path_by_artist:
    year_counter[year] += 1

# Lookup table for time_slice index v. year
time_slice_dict = {idx : year for (idx, year) in enumerate(sorted(year_counter))}
# List of counts for each time slice for DIM
time_seq = [year_counter[key] for key in sorted(year_counter.keys())]

print "Count of artists per each time slice:"
print time_seq
# Out:
# Count of artists per each time slice:
# [1, 1, 1, 1, 3, 1, 1, 1, 5, 3, 2, 2, 1, 2, 2, 1, 1, 2, 2, 5, 2, 2, 7, 2, 5, 5, 5, 6, 4, 6, 11, 15, 30, 42, 37, 64, 44, 44, 42, 52, 62, 49, 84, 73, 100, 113, 117, 112, 94, 135, 103, 133, 126, 131, 112, 141, 152, 167, 155, 156, 160, 141, 164, 171, 172, 182, 175, 194, 211, 203, 266, 272, 324, 360, 361, 431, 361, 382, 410, 407, 444, 440, 407, 420, 406, 410, 318, 350, 272, 299, 377, 390, 277, 264, 188, 3]

# %% [markdown]
# # Get most influential songs for each topic

# %%
# Create (num_songs, num_topics) array of influence scores
song_topic_inf_matrix = []

for time_idx in range(len(dim_model.time_slices)):    
    for song_idx in range(dim_model.time_slices[time_idx]):
        song_inf_by_topic = [None] * dim_model.num_topics

        for topic_idx in range(dim_model.num_topics):
            song_inf_by_topic[topic_idx] = dim_model.influences_time[time_idx][song_idx][topic_idx]
        
        song_topic_inf_matrix.append(song_inf_by_topic)

# %%
# Get the indices of the most influential songs per topic
most_inf_idx = np.array(song_topic_inf_matrix).argmax(axis=0)

for topic_no, artist_idx in enumerate(most_inf_idx):
    print "Topic:", topic_no
    # Lookup artist name
    print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
    # Lookup name of sample
    print os.listdir(bow_path_by_artist[artist_idx][1])[0]
    
    print
# Out:
# Topic: 0
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
#
# Topic: 1
# Sioux Falls
# 0_CopyPaste.npy
#
# Topic: 2
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
#
# Topic: 3
# Big Jaz
# 0_Jigga WhatFaint.npy
#
# Topic: 4
# Sioux Falls
# 0_CopyPaste.npy
#
# Topic: 5
# Big Jaz
# 0_Jigga WhatFaint.npy
#
# Topic: 6
# Warm Brew
# 0_Chiefing In the Streets.npy
#
# Topic: 7
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
#
# Topic: 8
# Carlinhos Brown
# 0_Passe Em Casa.npy
#
# Topic: 9
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy

# %% [markdown]
# # Get most influential songs per topic per epoch

# %%
song_topic_inf_by_year = []
song_topic_inf_matrix_copy = copy(song_topic_inf_matrix)

# Slice song-topic matrix into list of submatrices keyed by time slice
for time_idx, num_in_slice in enumerate(dim_model.time_slices):
    song_topic_inf_by_year.append(song_topic_inf_matrix_copy[:num_in_slice])
    del song_topic_inf_matrix_copy[:num_in_slice]

# %%
for idx, song_topic_matrix in enumerate(song_topic_inf_by_year):
    print time_slice_dict[idx], ':', time_seq[idx], 'songs'
    print "==============================="

    # Get the indices of the most influential songs per topic
    # Note: Need to adjust indexing since index resets to 0 for each new year
    most_inf_idx = np.array(song_topic_matrix).argmax(axis=0) + sum(dim_model.time_slices[:idx])

    for topic_no, artist_idx in enumerate(most_inf_idx):
        print "Topic:", topic_no
        # Lookup artist name
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
        # Lookup name of sample
        print os.listdir(bow_path_by_artist[artist_idx][1])[0]
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['main_genre'].iloc[0]
        print
# Out:
# 1912 : 1 songs
# ===============================
# Topic: 0
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 1
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 2
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 3
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 4
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 5
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 6
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 7
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 8
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 9
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# 1916 : 1 songs
# ===============================
# Topic: 0
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 1
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 2
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 3
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 4
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 5
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 6
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 7
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 8
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 9
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# 1919 : 1 songs
# ===============================
# Topic: 0
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 1
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 2
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 3
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 4
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 5
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 6
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 7
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 8
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 9
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# 1921 : 1 songs
# ===============================
# Topic: 0
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 1
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 2
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 3
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 4
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 5
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 6
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 7
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 8
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 9
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# 1923 : 3 songs
# ===============================
# Topic: 0
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 1
# Stacey Pullen
# 0_Kevin Saunderson as E-Dancer Foundation [Original Mix].npy
# Electronic
#
# Topic: 2
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 3
# Arnaldo Antunes
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 4
# Stacey Pullen
# 0_Kevin Saunderson as E-Dancer Foundation [Original Mix].npy
# Electronic
#
# Topic: 5
# Arnaldo Antunes
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 6
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 7
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 8
# Arnaldo Antunes
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 9
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# 1924 : 1 songs
# ===============================
# Topic: 0
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 1
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 2
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 3
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 4
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 5
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 6
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 7
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 8
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 9
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# 1926 : 1 songs
# ===============================
# Topic: 0
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 1
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 2
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 3
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 4
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 5
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 6
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 7
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 8
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 9
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# 1927 : 1 songs
# ===============================
# Topic: 0
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 1
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 2
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 3
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 4
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 5
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 6
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 7
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 8
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 9
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# 1928 : 5 songs
# ===============================
# Topic: 0
# Half Japanese
# 0_After Mendelssohn (137 Years)Paint It BlackArthur's ....npy
# Pop/Rock
#
# Topic: 1
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 2
# Conjunto Bernal
# 0_Para Que Quiero un Amor.npy
# Latin
#
# Topic: 3
# Orlando "Cachaito" Lopez
# 0_¿Y Tú Que Has Hecho?.npy
# Latin
#
# Topic: 4
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 5
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 6
# Half Japanese
# 0_After Mendelssohn (137 Years)Paint It BlackArthur's ....npy
# Pop/Rock
#
# Topic: 7
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 8
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 9
# Latin Playboys
# 0_Forever Night Shade Mary [From Show 78 "Night"].npy
# Pop/Rock
#
# 1929 : 3 songs
# ===============================
# Topic: 0
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 1
# Dubb Union
# 0_Hat 2 tha Bacc.npy
# Rap
#
# Topic: 2
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 3
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 4
# Dubb Union
# 0_Hat 2 tha Bacc.npy
# Rap
#
# Topic: 5
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 6
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 7
# Dubb Union
# 0_Hat 2 tha Bacc.npy
# Rap
#
# Topic: 8
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 9
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# 1930 : 2 songs
# ===============================
# Topic: 0
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 1
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 2
# Maurice Chevalier
# 0_I Love Paris.npy
# Vocal
#
# Topic: 3
# Maurice Chevalier
# 0_I Love Paris.npy
# Vocal
#
# Topic: 4
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 5
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 6
# Maurice Chevalier
# 0_I Love Paris.npy
# Vocal
#
# Topic: 7
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 8
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 9
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# 1931 : 2 songs
# ===============================
# Topic: 0
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 1
# Blonde Redhead
# 0_Futurism Vs. Passéism.npy
# Pop/Rock
#
# Topic: 2
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 3
# Blonde Redhead
# 0_Futurism Vs. Passéism.npy
# Pop/Rock
# Topic: 4
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 5
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 6
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 7
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 8
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 9
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# 1933 : 1 songs
# ===============================
# Topic: 0
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 1
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 2
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 3
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 4
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 5
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 6
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 7
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 8
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 9
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# 1935 : 2 songs
# ===============================
# Topic: 0
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 1
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 2
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 3
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 4
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 5
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 6
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 7
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 8
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 9
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# 1937 : 2 songs
# ===============================
# Topic: 0
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 1
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 2
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 3
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 4
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 5
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 6
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 7
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 8
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 9
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# 1938 : 1 songs
# ===============================
# Topic: 0
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 1
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 2
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 3
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 4
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 5
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 6
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 7
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 8
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 9
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# 1939 : 1 songs
# ===============================
# Topic: 0
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 1
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 2
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 3
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 4
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 5
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 6
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 7
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 8
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 9
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# 1940 : 2 songs
# ===============================
# Topic: 0
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 1
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 2
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 3
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 4
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 5
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 6
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 7
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 8
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 9
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# 1941 : 2 songs
# ===============================
# Topic: 0
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 1
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 2
# Sylvie Vartan
# 0_J'Ai un Problème.npy
# Pop/Rock
#
# Topic: 3
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 4
# Sylvie Vartan
# 0_J'Ai un Problème.npy
# Pop/Rock
#
# Topic: 5
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 6
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 7
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 8
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 9
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# 1942 : 5 songs
# ===============================
# Topic: 0
# Papoose
# 0_Touch It [RemixFeaturing Mary J. Blige, Rah Digga, Missy Elliot, Lloyd Banks, Papoose & DMX].npy
# Rap
#
# Topic: 1
# Colin Blunstone
# 0_London's Brilliant ParadeCaroline, Goodbye.npy
# Pop/Rock
#
# Topic: 2
# Papoose
# 0_Touch It [RemixFeaturing Mary J. Blige, Rah Digga, Missy Elliot, Lloyd Banks, Papoose & DMX].npy
# Rap
#
# Topic: 3
# The Barrett Sisters
# 0_I Shall Wear a Crown.npy
# Religious
#
# Topic: 4
# Colin Blunstone
# 0_London's Brilliant ParadeCaroline, Goodbye.npy
# Pop/Rock
#
# Topic: 5
# Electrik Red
# 0_So Good.npy
# R&B;
#
# Topic: 6
# Electrik Red
# 0_So Good.npy
# R&B;
#
# Topic: 7
# Electrik Red
# 0_So Good.npy
# R&B;
#
# Topic: 8
# Colin Blunstone
# 0_London's Brilliant ParadeCaroline, Goodbye.npy
# Pop/Rock
#
# Topic: 9
# The Barrett Sisters
# 0_I Shall Wear a Crown.npy
# Religious
#
# 1943 : 2 songs
# ===============================
# Topic: 0
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 1
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 2
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 3
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 4
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 5
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 6
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 7
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 8
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 9
# Chico Science
# 0_Macô.npy
# Latin
#
# 1944 : 2 songs
# ===============================
# Topic: 0
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 1
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 2
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 3
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 4
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 5
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 6
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 7
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 8
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 9
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# 1945 : 7 songs
# ===============================
# Topic: 0
# Perry Blake
# 0_Graines d'Etoiles.npy
# Pop/Rock
#
# Topic: 1
# Paul Carrack
# 0_Crying Won't Help You.npy
# Pop/Rock
#
# Topic: 2
# Paul Carrack
# 0_Crying Won't Help You.npy
# Pop/Rock
#
# Topic: 3
# Paul Carrack
# 0_Crying Won't Help You.npy
# Pop/Rock
#
# Topic: 4
# Kenny G
# 0_All the WayOne for My Baby (And One More for the Road).npy
# Jazz
#
# Topic: 5
# Paul Carrack
# 0_Crying Won't Help You.npy
# Pop/Rock
#
# Topic: 6
# Allan Sherman
# 0_Hello Muddah, Hello Fadduh! (A Letter from Camp).npy
# Comedy/Spoken
#
# Topic: 7
# Paul Carrack
# 0_Crying Won't Help You.npy
# Pop/Rock
#
# Topic: 8
# The Exploding Hearts
# 0_I'm a Pretender.npy
# Pop/Rock
#
# Topic: 9
# Perry Blake
# 0_Graines d'Etoiles.npy
# Pop/Rock
#
# 1946 : 2 songs
# ===============================
# Topic: 0
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 1
# Token Entry
# 0_Lucky Seven.npy
# Pop/Rock
#
# Topic: 2
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 3
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 4
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 5
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 6
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 7
# Token Entry
# 0_Lucky Seven.npy
# Pop/Rock
#
# Topic: 8
# Token Entry
# 0_Lucky Seven.npy
# Pop/Rock
#
# Topic: 9
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# 1947 : 5 songs
# ===============================
# Topic: 0
# 2 Live Jews
# 0_The Hustle (Parody: The Herschel).npy
# Comedy/Spoken
#
# Topic: 1
# Rickey Woodard
# 0_Rudolph the Red-Nosed Reindeer [Instrumental].npy
# Jazz
#
# Topic: 2
# Dickie Goodman
# 0_Russian Bandstand.npy
# Comedy/Spoken
#
# Topic: 3
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 4
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 5
# Rickey Woodard
# 0_Rudolph the Red-Nosed Reindeer [Instrumental].npy
# Jazz
#
# Topic: 6
# Dickie Goodman
# 0_Russian Bandstand.npy
# Comedy/Spoken
#
# Topic: 7
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 8
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 9
# 2 Live Jews
# 0_The Hustle (Parody: The Herschel).npy
# Comedy/Spoken
#
# 1948 : 5 songs
# ===============================
# Topic: 0
# Zurdok
# 0_Estático.npy
# Latin
#
# Topic: 1
# Zurdok
# 0_Estático.npy
# Latin
#
# Topic: 2
# Carl Reiner
# 0_2000 Year Old Man.npy
# Comedy/Spoken
#
# Topic: 3
# Tom Jobim
# 0_Águas De Março.npy
# Latin
#
# Topic: 4
# Billy Mitchell
# 0_Long Notes Blue (Here Is Cecco Beppe).npy
# Jazz
#
# Topic: 5
# Tom Jobim
# 0_Águas De Março.npy
# Latin
#
# Topic: 6
# Tom Jobim
# 0_Águas De Março.npy
# Latin
#
# Topic: 7
# Billy Mitchell
# 0_Long Notes Blue (Here Is Cecco Beppe).npy
# Jazz
#
# Topic: 8
# Billy Mitchell
# 0_Long Notes Blue (Here Is Cecco Beppe).npy
# Jazz
#
# Topic: 9
# Zurdok
# 0_Estático.npy
# Latin
#
# 1949 : 5 songs
# ===============================
# Topic: 0
# E.G. Kight
# 0_A Woman Can Tell.npy
# Blues
#
# Topic: 1
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 2
# Gene Kelly
# 0_I Begged Her.npy
# Vocal
#
# Topic: 3
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 4
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 5
# Eric Wood
# 0_Opus to Ecstasy.npy
# Folk
#
# Topic: 6
# Gene Kelly
# 0_I Begged Her.npy
# Vocal
#
# Topic: 7
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 8
# Eric Wood
# 0_Opus to Ecstasy.npy
# Folk
#
# Topic: 9
# E.G. Kight
# 0_A Woman Can Tell.npy
# Blues
#
# 1950 : 6 songs
# ===============================
# Topic: 0
# U-Roy
# 0_Wear You to the Ball.npy
# Reggae
#
# Topic: 1
# King Leg
# 0_Comfy ChairA Dream That Never Ends.npy
# Pop/Rock
#
# Topic: 2
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 3
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 4
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 5
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 6
# Streetwize
# 0_Don't Say Goodnight (It's Time for Love).npy
# Jazz
#
# Topic: 7
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 8
# King Leg
# 0_Comfy ChairA Dream That Never Ends.npy
# Pop/Rock
#
# Topic: 9
# U-Roy
# 0_Wear You to the Ball.npy
# Reggae
#
# 1951 : 4 songs
# ===============================
# Topic: 0
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 1
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 2
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 3
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 4
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 5
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 6
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 7
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 8
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 9
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# 1952 : 6 songs
# ===============================
# Topic: 0
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 1
# I Am the World Trade Center
# 0_Shoot You Down.npy
# Pop/Rock
#
# Topic: 2
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 3
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 4
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 5
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 6
# Leila
# 0_Activate, Pt. 1.npy
# Electronic
#
# Topic: 7
# I Am the World Trade Center
# 0_Shoot You Down.npy
# Pop/Rock
#
# Topic: 8
# Javen
# 0_Wipe Away My Tears.npy
# R&B;
#
# Topic: 9
# Eddie Holland
# 0_Super Woman (You Ain't No Ordinary Woman).npy
# R&B;
#
# 1953 : 11 songs
# ===============================
# Topic: 0
# Luciano
# 0_Neighbourhood Watch.npy
# Reggae
#
# Topic: 1
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 2
# Rob Henke
# 0_Christo Redemptor.npy
# Jazz
#
# Topic: 3
# Alex Sipiagin
# 0_Meditation on a Pair of Wire Cutters.npy
# Jazz
#
# Topic: 4
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 5
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 6
# Big L
# 0_Disciple of the Projects.npy
# Rap
#
# Topic: 7
# Luciano
# 0_Neighbourhood Watch.npy
# Reggae
#
# Topic: 8
# Jonn Hart
# 0_Winter Wonderland [Instrumental].npy
# R&B;
#
# Topic: 9
# Dennis Coffey
# 0_Grandmaster Flash Turntable Mix "Freestyle Mix": God Made Me Funky.npy
# R&B;
#
# 1954 : 15 songs
# ===============================
# Topic: 0
# Louis Armstrong
# 0_I'm Just a Lucky So and So.npy
# Jazz
#
# Topic: 1
# Kurupt
# 0_Dogg Pound Gangstaville.npy
# Rap
#
# Topic: 2
# Inez Andrews
# 0_I Shall Wear a Crown.npy
# Religious
#
# Topic: 3
# Louis Armstrong
# 0_I'm Just a Lucky So and So.npy
# Jazz
#
# Topic: 4
# Kurupt
# 0_Dogg Pound Gangstaville.npy
# Rap
#
# Topic: 5
# Spinderella
# 0_Gitty Up.npy
# Rap
#
# Topic: 6
# Luis Enrique
# 0_Yo No Sé Mañana.npy
# Latin
#
# Topic: 7
# Kurupt
# 0_Dogg Pound Gangstaville.npy
# Rap
#
# Topic: 8
# Winans Phase 2
# 0_This Train.npy
# Religious
#
# Topic: 9
# Basic Channel
# 0_OctagonEdit BlueContainThe SuperThe Climax For My ....npy
# Electronic
#
# 1955 : 30 songs
# ===============================
# Topic: 0
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 1
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 2
# JT the Bigga Figga
# 0_F*****' Is Good for U.npy
# Rap
#
# Topic: 3
# Poncho Sanchez
# 0_Chano Pozo Medley: Tin Tin DeoMantecaGuachi Guaro.npy
# Jazz
#
# Topic: 4
# Salif Keita
# 0_Burned with Desire.npy
# International
#
# Topic: 5
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 6
# JT the Bigga Figga
# 0_F*****' Is Good for U.npy
# Rap
#
# Topic: 7
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 8
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 9
# JT the Bigga Figga
# 0_F*****' Is Good for U.npy
# Rap
#
# 1956 : 42 songs
# ===============================
# Topic: 0
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 1
# Steve Cole
# 0_Chopsticks.npy
# Jazz
#
# Topic: 2
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 3
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 4
# Christafari
# 0_Never Let You Go.npy
# Religious
#
# Topic: 5
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 6
# Steve Cole
# 0_Chopsticks.npy
# Jazz
#
# Topic: 7
# Christafari
# 0_Never Let You Go.npy
# Religious
#
# Topic: 8
# Steve Cole
# 0_Chopsticks.npy
# Jazz
#
# Topic: 9
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# 1957 : 37 songs
# ===============================
# Topic: 0
# The BusBoys
# 0_Right Place, Wrong Time.npy
# Pop/Rock
#
# Topic: 1
# Tony Touch
# 0_Se Soltaron los Pitbulls.npy
# Rap
#
# Topic: 2
# Paulinho da Viola
# 0_Não Tenho Lágrimas.npy
# Latin
#
# Topic: 3
# Paulinho da Viola
# 0_Não Tenho Lágrimas.npy
# Latin
#
# Topic: 4
# Shawn Hook
# 0_Happy Xmas (War Is Over).npy
# Pop/Rock
#
# Topic: 5
# Ramatam
# 0_The LandRainy Sunday Evening.npy
# Pop/Rock
#
# Topic: 6
# Ramatam
# 0_The LandRainy Sunday Evening.npy
# Pop/Rock
#
# Topic: 7
# Tony Touch
# 0_Se Soltaron los Pitbulls.npy
# Rap
#
# Topic: 8
# Ramatam
# 0_The LandRainy Sunday Evening.npy
# Pop/Rock
#
# Topic: 9
# The BusBoys
# 0_Right Place, Wrong Time.npy
# Pop/Rock
#
# 1958 : 64 songs
# ===============================
# Topic: 0
# New Coon Creek Girls
# 0_Danny Boy.npy
# Country
#
# Topic: 1
# Dyke & the Blazers
# 0_We Got More Soul.npy
# R&B;
#
# Topic: 2
# Saetia
# 0_[Untitled Hidden Track].npy
# Pop/Rock
#
# Topic: 3
# Bomb the Bass
# 0_Bug Powder DustPump Me UpHow HighPoisonBeen Caught StealingI ....npy
# Electronic
#
# Topic: 4
# Jordan Rager
# 0_Southern Boy.npy
# Country
#
# Topic: 5
# Saetia
# 0_[Untitled Hidden Track].npy
# Pop/Rock
#
# Topic: 6
# Karen Carpenter
# 0_KarenElla Medley.npy
# Pop/Rock
#
# Topic: 7
# Bomb the Bass
# 0_Bug Powder DustPump Me UpHow HighPoisonBeen Caught StealingI ....npy
# Electronic
#
# Topic: 8
# Karen Carpenter
# 0_KarenElla Medley.npy
# Pop/Rock
#
# Topic: 9
# Garnett Silk
# 0_Love Is the Answer.npy
# Reggae
#
# 1959 : 44 songs
# ===============================
# Topic: 0
# Moonshine Bandits
# 0_Mud Digger Mega Remix.npy
# Rap
#
# Topic: 1
# Stresmatic
# 0_Knockin' at the Light.npy
# Rap
#
# Topic: 2
# Conrad Herwig
# 0_Seven Steps to Heaven.npy
# Jazz
#
# Topic: 3
# Pete Nice
# 0_Fallin Spiders.npy
# Rap
#
# Topic: 4
# Little Mike & the Tornadoes
# 0_What About Love.npy
# Blues
#
# Topic: 5
# Little Mike & the Tornadoes
# 0_What About Love.npy
# Blues
#
# Topic: 6
# Stresmatic
# 0_Knockin' at the Light.npy
# Rap
#
# Topic: 7
# Pete Nice
# 0_Fallin Spiders.npy
# Rap
#
# Topic: 8
# The Intruders
# 0_Just the Lonely Talkin' Again.npy
# R&B;
#
# Topic: 9
# Moonshine Bandits
# 0_Mud Digger Mega Remix.npy
# Rap
#
# 1960 : 44 songs
# ===============================
# Topic: 0
# Chill Rob G.
# 0_PowerSign Off.npy
# Rap
#
# Topic: 1
# The Melodians
# 0_Everybody Bawling.npy
# Reggae
#
# Topic: 2
# The Melodians
# 0_Everybody Bawling.npy
# Reggae
#
# Topic: 3
# Oliver Morgan
# 0_Trick Bag.npy
# R&B;
#
# Topic: 4
# Chill Rob G.
# 0_PowerSign Off.npy
# Rap
#
# Topic: 5
# Rita Lee
# 0_Refestança.npy
# Latin
#
# Topic: 6
# The Royal Guardsmen
# 0_Imperial Bedroom.npy
# Pop/Rock
#
# Topic: 7
# Chill Rob G.
# 0_PowerSign Off.npy
# Rap
#
# Topic: 8
# Chill Rob G.
# 0_PowerSign Off.npy
# Rap
#
# Topic: 9
# Hints
# 0_Foothills.npy
# Pop/Rock
#
# 1961 : 42 songs
# ===============================
# Topic: 0
# Tito Nieves
# 0_Sonámbulo.npy
# Latin
#
# Topic: 1
# Jordan Fisher
# 0_Gotta Be Me.npy
# Pop/Rock
#
# Topic: 2
# Elaine Stritch
# 0_Don't Go to Bed with a Frown.npy
# Vocal
#
# Topic: 3
# Elaine Stritch
# 0_Don't Go to Bed with a Frown.npy
# Vocal
#
# Topic: 4
# Justin Warfield
# 0_Brother's Gonna Work It OutNot Just Another Drug Store.npy
# Rap
#
# Topic: 5
# Justin Warfield
# 0_Brother's Gonna Work It OutNot Just Another Drug Store.npy
# Rap
#
# Topic: 6
# Elaine Stritch
# 0_Don't Go to Bed with a Frown.npy
# Vocal
#
# Topic: 7
# Jordan Fisher
# 0_Gotta Be Me.npy
# Pop/Rock
#
# Topic: 8
# Justin Warfield
# 0_Brother's Gonna Work It OutNot Just Another Drug Store.npy
# Rap
#
# Topic: 9
# Tito Nieves
# 0_Sonámbulo.npy
# Latin
#
# 1962 : 52 songs
# ===============================
# Topic: 0
# Brazilian Girls
# 0_Aquele Abraço.npy
# Pop/Rock
#
# Topic: 1
# Misfits
# 0_Pretentious.npy
# Pop/Rock
#
# Topic: 2
# Johnny Farmer
# 0_Death Letter [Organized Noize Rmx].npy
# Blues
#
# Topic: 3
# Pierre Bensusan
# 0_Les Places de Liberté.npy
# New Age
#
# Topic: 4
# Toño Rosario
# 0_Amigo Mio.npy
# Latin
#
# Topic: 5
# Pierre Bensusan
# 0_Les Places de Liberté.npy
# New Age
#
# Topic: 6
# Johnny Osbourne
# 0_No Ice Cream Sound.npy
# Reggae
#
# Topic: 7
# Johnny Osbourne
# 0_No Ice Cream Sound.npy
# Reggae
#
# Topic: 8
# Misfits
# 0_Pretentious.npy
# Pop/Rock
#
# Topic: 9
# Jayne County & the Electric Chairs
# 0_Fun in Amerika.npy
# Pop/Rock
#
# 1963 : 62 songs
# ===============================
# Topic: 0
# Los Tres Diamantes
# 0_Usted.npy
# Latin
#
# Topic: 1
# Yami Bolo
# 0_Stand a ChanceAnd You Be Loved.npy
# Reggae
#
# Topic: 2
# Wendell B.
# 0_Definition of a Real Man.npy
# R&B;
#
# Topic: 3
# Chuck Wayne
# 0_Conception.npy
# Jazz
#
# Topic: 4
# Charles Aznavour
# 0_J'Aime Paris au Mois de Mai.npy
# Vocal
#
# Topic: 5
# Charles Aznavour
# 0_J'Aime Paris au Mois de Mai.npy
# Vocal
#
# Topic: 6
# Chuck Wayne
# 0_Conception.npy
# Jazz
#
# Topic: 7
# Yami Bolo
# 0_Stand a ChanceAnd You Be Loved.npy
# Reggae
#
# Topic: 8
# Charles Aznavour
# 0_J'Aime Paris au Mois de Mai.npy
# Vocal
#
# Topic: 9
# Omar Pene
# 0_Saï Saï Sida (AIDS the Devil).npy
# International
#
# 1964 : 49 songs
# ===============================
# Topic: 0
# Big Brother & the Holding Company
# 0_Medley: Amazing GraceHi Heel Sneekers.npy
# Pop/Rock
#
# Topic: 1
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# Topic: 2
# The Artifacts
# 0_Cummin' Thru Ya Fuckin' Block [Remix].npy
# Rap
#
# Topic: 3
# Red Meat
# 0_High Maintenance Babe.npy
# Country
#
# Topic: 4
# The Artifacts
# 0_Cummin' Thru Ya Fuckin' Block [Remix].npy
# Rap
#
# Topic: 5
# Tone-Loc
# 0_Happy (Spiritual South Go Happy in Rio)Funky Cold Medina R.npy
# Rap
#
# Topic: 6
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# Topic: 7
# The Artifacts
# 0_Cummin' Thru Ya Fuckin' Block [Remix].npy
# Rap
#
# Topic: 8
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# Topic: 9
# Septeto Nacional de Ignacio Piñeiro
# 0_Suavecito.npy
# Latin
#
# 1965 : 84 songs
# ===============================
# Topic: 0
# Tupac Shakur
# 0_BiggieTupac Live Freestyle.npy
# Rap
#
# Topic: 1
# MC Paul Barman
# 0_Salvation Barny.npy
# Rap
#
# Topic: 2
# Jakko
# 0_Carioca.npy
# Pop/Rock
#
# Topic: 3
# Cold Blood
# 0_Understanding.npy
# Pop/Rock
#
# Topic: 4
# Cold Blood
# 0_Understanding.npy
# Pop/Rock
#
# Topic: 5
# Cold Blood
# 0_Understanding.npy
# Pop/Rock
#
# Topic: 6
# George Tandy, Jr.
# 0_Jaded.npy
# R&B;
#
# Topic: 7
# Martin Sexton
# 0_Revelry.npy
# Folk
#
# Topic: 8
# George Tandy, Jr.
# 0_Jaded.npy
# R&B;
#
# Topic: 9
# Urban Tribe
# 0_Sand in My Slide Shuffle.npy
# Electronic
#
# 1966 : 73 songs
# ===============================
# Topic: 0
# Ms. Jody
# 0_Take Me.npy
# R&B;
#
# Topic: 1
# 50 Cent
# 0_All of Me.npy
# Rap
#
# Topic: 2
# Cabas
# 0_Mi Bombón.npy
# Latin
#
# Topic: 3
# The Lettermen
# 0_The Way You Look Tonight.npy
# Vocal
#
# Topic: 4
# Fictionist
# 0_Right Now.npy
# Pop/Rock
#
# Topic: 5
# Mickey & Sylvia
# 0_Love Is Strange.npy
# R&B;
#
# Topic: 6
# Bob Andy
# 0_I've Got to Go Back Home.npy
# Reggae
#
# Topic: 7
# Cabas
# 0_Mi Bombón.npy
# Latin
#
# Topic: 8
# Mickey & Sylvia
# 0_Love Is Strange.npy
# R&B;
#
# Topic: 9
# Bryan-Michael Cox
# 0_Throw the Smack DownCan't Give You UpThis.npy
# R&B;
#
# 1967 : 100 songs
# ===============================
# Topic: 0
# Kagbe Sidibe
# 0_Kouloumba.npy
# International
#
# Topic: 1
# James Montgomery Band
# 0_Smokeys Barbecue.npy
# Blues
#
# Topic: 2
# James Montgomery Band
# 0_Smokeys Barbecue.npy
# Blues
#
# Topic: 3
# Hooverphonic
# 0_Uno Más.npy
# Pop/Rock
#
# Topic: 4
# Morgan Heritage
# 0_Down by the River.npy
# Reggae
#
# Topic: 5
# James Montgomery Band
# 0_Smokeys Barbecue.npy
# Blues
#
# Topic: 6
# Nora Jean Bruso
# 0_Things Done Chamged.npy
# Blues
#
# Topic: 7
# Morgan Heritage
# 0_Down by the River.npy
# Reggae
#
# Topic: 8
# James Montgomery Band
# 0_Smokeys Barbecue.npy
# Blues
#
# Topic: 9
# Kagbe Sidibe
# 0_Kouloumba.npy
# International
#
# 1968 : 113 songs
# ===============================
# Topic: 0
# Johnnie Ray
# 0_Let's Walk That-A-Way.npy
# Vocal
#
# Topic: 1
# Guy Lombardo
# 0_Christmas Island.npy
# Easy Listening
#
# Topic: 2
# The Robins
# 0_Smokey Joe's Cafe.npy
# R&B;
#
# Topic: 3
# Léo Ferré
# 0_Paris Canaille.npy
# Vocal
#
# Topic: 4
# Jackson Do Pandeiro
# 0_Sebastiana.npy
# Latin
#
# Topic: 5
# Johnnie Ray
# 0_Let's Walk That-A-Way.npy
# Vocal
#
# Topic: 6
# Hank Thompson
# 0_Humpty Dumpty Heart.npy
# Country
#
# Topic: 7
# Peggy Lee
# 0_You Was.npy
# Vocal
#
# Topic: 8
# The Robins
# 0_Smokey Joe's Cafe.npy
# R&B;
#
# Topic: 9
# Tommy Duncan
# 0_Bubbles in My Beer.npy
# Country
#
# 1969 : 117 songs
# ===============================
# Topic: 0
# The Four Preps
# 0_26 Miles (Santa Catalina).npy
# Vocal
#
# Topic: 1
# The Four Preps
# 0_26 Miles (Santa Catalina).npy
# Vocal
#
# Topic: 2
# The Ames Brothers
# 0_Rag Mop.npy
# Vocal
#
# Topic: 3
# Cutty Cutshall
# 0_Someday You'll Be Sorry.npy
# Jazz
#
# Topic: 4
# Cutty Cutshall
# 0_Someday You'll Be Sorry.npy
# Jazz
#
# Topic: 5
# Jim Dandy
# 0_Jim Dandy.npy
# Pop/Rock
#
# Topic: 6
# Screamin' Jay Hawkins
# 0_Little Demon.npy
# R&B;
#
# Topic: 7
# Jim Dandy
# 0_Jim Dandy.npy
# Pop/Rock
#
# Topic: 8
# Screamin' Jay Hawkins
# 0_Little Demon.npy
# R&B;
#
# Topic: 9
# Jack Marshall
# 0_Fever.npy
# Jazz
#
# 1970 : 112 songs
# ===============================
# Topic: 0
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 1
# Brian Hyland
# 0_Itsy Bitsy Teenie Weenie Yellow Polka Dot Bikini.npy
# Pop/Rock
#
# Topic: 2
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 3
# Buddy Knox
# 0_I Think I'm Gonna Kill Myself.npy
# Pop/Rock
#
# Topic: 4
# Sam Cooke
# 0_Chain Gang.npy
# R&B;
#
# Topic: 5
# Keely Smith
# 0_How Are Ya' Fixed For Love?.npy
# Vocal
#
# Topic: 6
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 7
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 8
# Anthony Newley
# 0_Why.npy
# Vocal
#
# Topic: 9
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# 1971 : 94 songs
# ===============================
# Topic: 0
# Ben E. King
# 0_Spanish Harlem.npy
# R&B;
#
# Topic: 1
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# Topic: 2
# Hank Marvin
# 0_Wonderful Land.npy
# Pop/Rock
#
# Topic: 3
# The Raelettes
# 0_You Are My Sunshine.npy
# R&B;
#
# Topic: 4
# John Barry
# 0_James Bond Theme.npy
# Stage & Screen
#
# Topic: 5
# Clara Ward
# 0_How I Got Over.npy
# Religious
#
# Topic: 6
# John Barry
# 0_James Bond Theme.npy
# Stage & Screen
#
# Topic: 7
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# Topic: 8
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# Topic: 9
# The Marvelettes
# 0_Playboy.npy
# R&B;
#
# 1972 : 135 songs
# ===============================
# Topic: 0
# Lola Flores
# 0_A Tu Vera.npy
# Latin
#
# Topic: 1
# The Shadows
# 0_The Stranger.npy
# Pop/Rock
#
# Topic: 2
# Walter Jackson
# 0_It's All Over.npy
# R&B;
#
# Topic: 3
# The Shadows
# 0_The Stranger.npy
# Pop/Rock
#
# Topic: 4
# Jerry Butler
# 0_For Your Precious Love.npy
# R&B;
#
# Topic: 5
# Sylvia Syms
# 0_You Fascinate Me So.npy
# Vocal
#
# Topic: 6
# Connie Francis
# 0_Second Hand Love.npy
# Pop/Rock
#
# Topic: 7
# Bobby Vinton
# 0_Mr. Lonely.npy
# Vocal
#
# Topic: 8
# The Angels
# 0_My Boyfriend's Back.npy
# Pop/Rock
#
# Topic: 9
# Sandie Shaw
# 0_(There's) Always Something There to Remind Me.npy
# Pop/Rock
#
# 1973 : 103 songs
# ===============================
# Topic: 0
# Jon Hendricks
# 0_Fire in the City.npy
# Vocal
#
# Topic: 1
# The Outsiders
# 0_Time Won't Let Me.npy
# Pop/Rock
#
# Topic: 2
# Burl Ives
# 0_A Holly Jolly Christmas.npy
# Folk
#
# Topic: 3
# Gil Fuller
# 0_Be's That Way.npy
# Jazz
#
# Topic: 4
# The Knickerbockers
# 0_Lies.npy
# Pop/Rock
#
# Topic: 5
# Jon Hendricks
# 0_Fire in the City.npy
# Vocal
#
# Topic: 6
# Pilgrim Travelers
# 0_Motherless Child.npy
# Religious
#
# Topic: 7
# Peppermint Harris
# 0_Bad Bad Whiskey.npy
# Blues
#
# Topic: 8
# Joe Hinton
# 0_Funny (How Time Slips Away).npy
# R&B;
#
# Topic: 9
# The Statler Brothers
# 0_Flowers on the Wall.npy
# Country
#
# 1974 : 133 songs
# ===============================
# Topic: 0
# Ray Price
# 0_I'm Still Not over You.npy
# Country
#
# Topic: 1
# Tammi Terrell
# 0_If I Could Build My Whole World Around You.npy
# R&B;
#
# Topic: 2
# Tammi Terrell
# 0_If I Could Build My Whole World Around You.npy
# R&B;
#
# Topic: 3
# Ray Price
# 0_I'm Still Not over You.npy
# Country
#
# Topic: 4
# Jack Bruce
# 0_White Room.npy
# Pop/Rock
#
# Topic: 5
# O.V. Wright
# 0_Eight Men, Four Women.npy
# R&B;
#
# Topic: 6
# Ray Price
# 0_I'm Still Not over You.npy
# Country
#
# Topic: 7
# O.V. Wright
# 0_Eight Men, Four Women.npy
# R&B;
#
# Topic: 8
# Jack Bruce
# 0_White Room.npy
# Pop/Rock
#
# Topic: 9
# Herman's Hermits
# 0_There's a Kind of Hush (All Over the World).npy
# Pop/Rock
#
# 1975 : 126 songs
# ===============================
# Topic: 0
# Buzzy Linhart
# 0_Yellow Cab.npy
# Folk
#
# Topic: 1
# Scott Walker
# 0_Jackie.npy
# Pop/Rock
#
# Topic: 2
# Betty Harris
# 0_Ride Your Pony.npy
# R&B;
#
# Topic: 3
# Nat King Cole
# 0_Long Long Ago.npy
# Jazz
#
# Topic: 4
# The United States of America
# 0_The Garden of Earthly Delights.npy
# Pop/Rock
#
# Topic: 5
# Jane Birkin
# 0_Je T'Aime Moi Non Plus.npy
# Pop/Rock
#
# Topic: 6
# Clancy Eccles
# 0_C.N. Express.npy
# Reggae
#
# Topic: 7
# Clancy Eccles
# 0_C.N. Express.npy
# Reggae
#
# Topic: 8
# Clancy Eccles
# 0_C.N. Express.npy
# Reggae
#
# Topic: 9
# Roger Nichols
# 0_I Can See Only You.npy
# Pop/Rock
#
# 1976 : 131 songs
# ===============================
# Topic: 0
# The Wailers
# 0_Duppy Conqueror.npy
# Reggae
#
# Topic: 1
# Sam & Dave
# 0_Said I Wasn't Gonna Tell Nobody.npy
# R&B;
#
# Topic: 2
# J.T. Brown
# 0_I Can't Hold Out.npy
# Blues
#
# Topic: 3
# J.T. Brown
# 0_I Can't Hold Out.npy
# Blues
#
# Topic: 4
# The Wailers
# 0_Duppy Conqueror.npy
# Reggae
#
# Topic: 5
# The Wailers
# 0_Duppy Conqueror.npy
# Reggae
#
# Topic: 6
# Sam & Dave
# 0_Said I Wasn't Gonna Tell Nobody.npy
# R&B;
#
# Topic: 7
# The Wailers
# 0_Duppy Conqueror.npy
# Reggae
#
# Topic: 8
# The Wailers
# 0_Duppy Conqueror.npy
# Reggae
#
# Topic: 9
# El Chicano
# 0_Viva Tirado.npy
# Pop/Rock
#
# 1977 : 112 songs
# ===============================
# Topic: 0
# The Jimi Hendrix Experience
# 0_Manic Depression.npy
# Pop/Rock
#
# Topic: 1
# Jethro Tull
# 0_My God.npy
# Pop/Rock
# Topic: 2
# Michael Nesmith
# 0_Joanne.npy
# Pop/Rock
#
# Topic: 3
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 4
# Michael Nesmith
# 0_Joanne.npy
# Pop/Rock
#
# Topic: 5
# Jethro Tull
# 0_My God.npy
# Pop/Rock
#
# Topic: 6
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 7
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 8
# Michael Nesmith
# 0_Joanne.npy
# Pop/Rock
#
# Topic: 9
# Los del Rio
# 0_La Canto.npy
# Latin
#
# 1978 : 141 songs
# ===============================
# Topic: 0
# Dallas Frazier
# 0_The Laying on of Hands.npy
# Country
#
# Topic: 1
# Johnny Nash
# 0_Stir It Up.npy
# R&B;
#
# Topic: 2
# Armando Peraza
# 0_Geechee Girl.npy
# Jazz
#
# Topic: 3
# Son Seals
# 0_We Wish You a Merry Christmas.npy
# Blues
#
# Topic: 4
# Paul Simon
# 0_Kodachrome.npy
# Pop/Rock
#
# Topic: 5
# Thom Bell
# 0_You'll Never Get to Heaven (If You Break My Heart).npy
# R&B;
#
# Topic: 6
# Johnny Nash
# 0_Stir It Up.npy
# R&B;
#
# Topic: 7
# Thom Bell
# 0_You'll Never Get to Heaven (If You Break My Heart).npy
# R&B;
#
# Topic: 8
# G. Love
# 0_Rainbow.npy
# Pop/Rock
#
# Topic: 9
# Albert Hammond
# 0_It Never Rains in Southern California.npy
# Pop/Rock
#
# 1979 : 152 songs
# ===============================
# Topic: 0
# Fred Astaire
# 0_Top Hat, White Tie and Tails.npy
# Vocal
#
# Topic: 1
# Highway 101
# 0_Young Country.npy
# Country
#
# Topic: 2
# Grand Funk Railroad
# 0_Some Kind of Wonderful.npy
# Pop/Rock
#
# Topic: 3
# Jimmy Witherspoon
# 0_Ain't Nobody's Business.npy
# Blues
#
# Topic: 4
# Highway 101
# 0_Young Country.npy
# Country
#
# Topic: 5
# Ramón Ayala
# 0_Por Tus Caprichos.npy
# Latin
#
# Topic: 6
# Bronislaw Kaper
# 0_On Green Dolphin Street : On Green Dolphin Street.npy
# Stage & Screen
#
# Topic: 7
# The Heptones
# 0_Book of Rules.npy
# Reggae
#
# Topic: 8
# Highway 101
# 0_Young Country.npy
# Country
#
# Topic: 9
# Motion Man
# 0_In the End.npy
# Rap
#
# 1980 : 167 songs
# ===============================
# Topic: 0
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 1
# Phoebe Snow
# 0_Gone at Last.npy
# Pop/Rock
#
# Topic: 2
# Phoebe Snow
# 0_Gone at Last.npy
# Pop/Rock
#
# Topic: 3
# Grover Washington, Jr.
# 0_Mister Magic.npy
# Jazz
#
# Topic: 4
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 5
# Michael Franks
# 0_Popsicle Toes.npy
# Vocal
#
# Topic: 6
# Phoebe Snow
# 0_Gone at Last.npy
# Pop/Rock
#
# Topic: 7
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 8
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 9
# Scott 4
# 0_East Winter.npy
# Pop/Rock
#
# 1981 : 155 songs
# ===============================
# Topic: 0
# George Benson
# 0_Breezin'.npy
# Jazz
#
# Topic: 1
# Sha Na Na
# 0_At the Hop.npy
# Pop/Rock
#
# Topic: 2
# George Benson
# 0_Breezin'.npy
# Jazz
#
# Topic: 3
# Victor Feldman
# 0_Aja.npy
# Jazz
#
# Topic: 4
# The Brothers Johnson
# 0_Strawberry Letter 23.npy
# R&B;
#
# Topic: 5
# Rose Royce
# 0_Car Wash.npy
# R&B;
#
# Topic: 6
# George Benson
# 0_Breezin'.npy
# Jazz
#
# Topic: 7
# George Benson
# 0_Breezin'.npy
# Jazz
#
# Topic: 8
# The Brothers Johnson
# 0_Strawberry Letter 23.npy
# R&B;
#
# Topic: 9
# The Angels
# 0_Am I Ever Gonna See Your Face Again.npy
# Pop/Rock
#
# 1982 : 156 songs
# ===============================
# Topic: 0
# Natalie Cole
# 0_This Will Be (An Everlasting Love).npy
# R&B;
#
# Topic: 1
# Herb Alpert
# 0_A Taste of Honey.npy
# Easy Listening
#
# Topic: 2
# Stuff
# 0_Signed, Sealed, Delivered I'm Yours.npy
# R&B;
#
# Topic: 3
# Stuff
# 0_Signed, Sealed, Delivered I'm Yours.npy
# R&B;
#
# Topic: 4
# Herb Alpert
# 0_A Taste of Honey.npy
# Easy Listening
#
# Topic: 5
# Herb Alpert
# 0_A Taste of Honey.npy
# Easy Listening
#
# Topic: 6
# Nickolas Ashford
# 0_Stuff Like That.npy
# R&B;
#
# Topic: 7
# Tony Orlando
# 0_Bring It on Home to Me.npy
# Pop/Rock
#
# Topic: 8
# National Lampoon
# 0_Mr. Roberts #2.npy
# Comedy/Spoken
#
# Topic: 9
# Lene Lovich
# 0_Lucky Number.npy
# Pop/Rock
#
# 1983 : 160 songs
# ===============================
# Topic: 0
# Stevie Wonder
# 0_One Little Christmas Tree.npy
# R&B;
#
# Topic: 1
# Seals & Crofts
# 0_Summer Breeze.npy
# Pop/Rock
#
# Topic: 2
# Seals & Crofts
# 0_Summer Breeze.npy
# Pop/Rock
#
# Topic: 3
# Justin Tubb
# 0_Blue Eyed Elaine.npy
# Country
#
# Topic: 4
# Chris LeDoux
# 0_Copenhagen.npy
# Country
#
# Topic: 5
# Jack Ingram
# 0_Why Me.npy
# Country
#
# Topic: 6
# Seals & Crofts
# 0_Summer Breeze.npy
# Pop/Rock
#
# Topic: 7
# Jah Thomas
# 0_Answer the Telephone.npy
# Reggae
#
# Topic: 8
# Seals & Crofts
# 0_Summer Breeze.npy
# Pop/Rock
#
# Topic: 9
# Stevie Wonder
# 0_One Little Christmas Tree.npy
# R&B;
#
# 1984 : 141 songs
# ===============================
# Topic: 0
# Anne Murray
# 0_You Needed Me.npy
# Country
#
# Topic: 1
# Graham Parker & the Rumour
# 0_Soul Shoes.npy
# Pop/Rock
#
# Topic: 2
# Rossington Collins Band
# 0_Don't Misunderstand Me.npy
# Pop/Rock
#
# Topic: 3
# Shalamar
# 0_Make That Move.npy
# R&B;
#
# Topic: 4
# Anne Murray
# 0_You Needed Me.npy
# Country
#
# Topic: 5
# Maze
# 0_Joy and Pain.npy
# R&B;
#
# Topic: 6
# A+
# 0_Gusto.npy
# Rap
#
# Topic: 7
# Kurtis Blow
# 0_The Breaks.npy
# Rap
#
# Topic: 8
# Anne Murray
# 0_You Needed Me.npy
# Country
#
# Topic: 9
# Joan Jett
# 0_Bad Reputation.npy
# Pop/Rock
#
# 1985 : 164 songs
# ===============================
# Topic: 0
# Men at Work
# 0_Who Can It Be Now?.npy
# Pop/Rock
#
# Topic: 1
# Quarterflash
# 0_Harden My Heart.npy
# Pop/Rock
#
# Topic: 2
# Pierre Moerlen
# 0_Leave It Open.npy
# Electronic
#
# Topic: 3
# Wynton Marsalis
# 0_My Funny Valentine.npy
# Jazz
#
# Topic: 4
# Zapp
# 0_More Bounce to the Ounce.npy
# R&B;
#
# Topic: 5
# Grace Jones
# 0_Pull up to the Bumper.npy
# R&B;
#
# Topic: 6
# Dirk Bogarde
# 0_A Foggy Day.npy
# Vocal
#
# Topic: 7
# Lakeside
# 0_Fantastic Voyage.npy
# R&B;
#
# Topic: 8
# GIRLI
# 0_Not That Girl.npy
# Electronic
#
# Topic: 9
# Men at Work
# 0_Who Can It Be Now?.npy
# Pop/Rock
#
# 1986 : 171 songs
# ===============================
# Topic: 0
# Slow Children
# 0_President Am I.npy
# Pop/Rock
#
# Topic: 1
# Eddy Grant
# 0_I Don't Wanna Dance.npy
# Reggae
#
# Topic: 2
# Crass
# 0_Birth Control 'N' Rock 'N' Roll.npy
# Pop/Rock
#
# Topic: 3
# Japan
# 0_Ghosts.npy
# Pop/Rock
#
# Topic: 4
# Kajagoogoo
# 0_Too Shy.npy
# Pop/Rock
#
# Topic: 5
# Merle Haggard
# 0_Pancho & Lefty.npy
# Country
#
# Topic: 6
# Merle Haggard
# 0_Pancho & Lefty.npy
# Country
#
# Topic: 7
# Eddy Grant
# 0_I Don't Wanna Dance.npy
# Reggae
#
# Topic: 8
# The Shaggs
# 0_Shaggs' Own Thing.npy
# Pop/Rock
#
# Topic: 9
# Circle Jerks
# 0_Wild in the Streets.npy
# Pop/Rock
#
# 1987 : 172 songs
# ===============================
# Topic: 0
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 1
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 2
# Chet Atkins
# 0_We Didn't See a Thing.npy
# Country
#
# Topic: 3
# Howard Devoto
# 0_Cold Imagination.npy
# Pop/Rock
#
# Topic: 4
# Rufus
# 0_Ain't Nobody.npy
# R&B;
#
# Topic: 5
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 6
# Rufus
# 0_Ain't Nobody.npy
# R&B;
#
# Topic: 7
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 8
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 9
# Alicia Myers
# 0_I Want to Thank You.npy
# R&B;
#
# 1988 : 182 songs
# ===============================
# Topic: 0
# Dimples D.
# 0_Sucker D.J.'s (I Will Survive).npy
# Rap
#
# Topic: 1
# Spinal Tap
# 0_Big Bottom.npy
# Comedy/Spoken
#
# Topic: 2
# The Real Roxanne
# 0_The Real Roxanne.npy
# Rap
#
# Topic: 3
# K. Michelle
# 0_Ride Out.npy
# R&B;
#
# Topic: 4
# General Public
# 0_Tenderness.npy
# Pop/Rock
#
# Topic: 5
# Ambitious Lovers
# 0_Let's Be Adult.npy
# Pop/Rock
#
# Topic: 6
# K. Michelle
# 0_Ride Out.npy
# R&B;
#
# Topic: 7
# Konk
# 0_Your Life.npy
# Pop/Rock
#
# Topic: 8
# The Real Roxanne
# 0_The Real Roxanne.npy
# Rap
#
# Topic: 9
# Arrow
# 0_Hot Hot Hot.npy
# International
#
# 1989 : 175 songs
# ===============================
# Topic: 0
# Carlene Davis
# 0_Bits and Pieces.npy
# Reggae
#
# Topic: 1
# The Young Fresh Fellows
# 0_Margaret.npy
# Pop/Rock
#
# Topic: 2
# Marilyn Monroe
# 0_Down in the Meadow.npy
# Vocal
#
# Topic: 3
# L.A. Dream Team
# 0_Medley.npy
# Rap
#
# Topic: 4
# Han Bennink
# 0_Change of Season.npy
# Jazz
#
# Topic: 5
# Han Bennink
# 0_Change of Season.npy
# Jazz
#
# Topic: 6
# Han Bennink
# 0_Change of Season.npy
# Jazz
#
# Topic: 7
# Bugs Bunny
# 0_Happy Trails.npy
# Children's
#
# Topic: 8
# Han Bennink
# 0_Change of Season.npy
# Jazz
#
# Topic: 9
# Carlene Davis
# 0_Bits and Pieces.npy
# Reggae
#
# 1990 : 194 songs
# ===============================
# Topic: 0
# Larry Graham
# 0_If You Need My Love Tonight.npy
# R&B;
#
# Topic: 1
# Larry Graham
# 0_If You Need My Love Tonight.npy
# R&B;
#
# Topic: 2
# Kenny Loggins
# 0_Danger Zone.npy
# Pop/Rock
#
# Topic: 3
# Emily Remler
# 0_Imagination.npy
# Jazz
#
# Topic: 4
# Kenny Loggins
# 0_Danger Zone.npy
# Pop/Rock
#
# Topic: 5
# David Allan Coe
# 0_I Hate Love.npy
# Country
#
# Topic: 6
# The Controllers
# 0_Got a Thang.npy
# R&B;
#
# Topic: 7
# Kenny Loggins
# 0_Danger Zone.npy
# Pop/Rock
#
# Topic: 8
# Kenny Loggins
# 0_Danger Zone.npy
# Pop/Rock
#
# Topic: 9
# Steady B
# 0_Bring the Beat Back.npy
# Rap
#
# 1991 : 211 songs
# ===============================
# Topic: 0
# Atlantic Starr
# 0_Always.npy
# R&B;
#
# Topic: 1
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 2
# M/A/R/R/S
# 0_Pump Up the Volume.npy
# Electronic
#
# Topic: 3
# Tom Scott
# 0_Garden of Earthly Delights.npy
# Jazz
#
# Topic: 4
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 5
# M/A/R/R/S
# 0_Pump Up the Volume.npy
# Electronic
#
# Topic: 6
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 7
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 8
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 9
# Meli'sa Morgan
# 0_Love Changes.npy
# R&B;
#
# 1992 : 203 songs
# ===============================
# Topic: 0
# Aster Aweke
# 0_Tizita (Memories).npy
# International
#
# Topic: 1
# Skid Row
# 0_18 and Life.npy
# Pop/Rock
#
# Topic: 2
# House of Freaks
# 0_Crack in the Sidewalk.npy
# Pop/Rock
#
# Topic: 3
# Mike Reid
# 0_Old Folks.npy
# Country
#
# Topic: 4
# Vixen
# 0_Cryin'.npy
# Pop/Rock
#
# Topic: 5
# Bobby McFerrin
# 0_Don't Worry Be Happy.npy
# Vocal
#
# Topic: 6
# Bobby McFerrin
# 0_Don't Worry Be Happy.npy
# Vocal
#
# Topic: 7
# 3rd Bass
# 0_The Gas Face.npy
# Rap
#
# Topic: 8
# The Andrews Sisters
# 0_Here Comes Santa Claus.npy
# Vocal
#
# Topic: 9
# Aster Aweke
# 0_Tizita (Memories).npy
# International
#
# 1993 : 266 songs
# ===============================
# Topic: 0
# Swampwater
# 0_Freeborn Man.npy
# Pop/Rock
#
# Topic: 1
# Dave Hole
# 0_Short Fuse Blues.npy
# Blues
#
# Topic: 2
# Swampwater
# 0_Freeborn Man.npy
# Pop/Rock
#
# Topic: 3
# Big Walter Horton
# 0_Walking by Myself.npy
# Blues
#
# Topic: 4
# Dave Hole
# 0_Short Fuse Blues.npy
# Blues
#
# Topic: 5
# Lakim Shabazz
# 0_1, 2, 3.npy
# Rap
#
# Topic: 6
# Adamski
# 0_Killer.npy
# Electronic
#
# Topic: 7
# Dave Hole
# 0_Short Fuse Blues.npy
# Blues
#
# Topic: 8
# Luther "Houserocker" Johnson
# 0_Trouble Blues.npy
# Blues
#
# Topic: 9
# Poor Righteous Teachers
# 0_Rock Dis Funky Joint.npy
# Rap
#
# 1994 : 272 songs
# ===============================
# Topic: 0
# Seal
# 0_Killer.npy
# Pop/Rock
#
# Topic: 1
# Joe Satriani
# 0_Hey Stoopid.npy
# Pop/Rock
#
# Topic: 2
# Roy Rogers
# 0_Rodeo Road.npy
# Country
#
# Topic: 3
# Mark Chesnutt
# 0_Bubba Shot the Jukebox.npy
# Country
#
# Topic: 4
# Elton John
# 0_Don't Let the Sun Go Down on Me.npy
# Pop/Rock
#
# Topic: 5
# Elton John
# 0_Don't Let the Sun Go Down on Me.npy
# Pop/Rock
#
# Topic: 6
# 2nd II None
# 0_Skanless.npy
# Rap
#
# Topic: 7
# 2nd II None
# 0_Skanless.npy
# Rap
#
# Topic: 8
# Seal
# 0_Killer.npy
# Pop/Rock
#
# Topic: 9
# Lee Allen
# 0_Everyday I Have the Blues.npy
# R&B;
#
# 1995 : 324 songs
# ===============================
# Topic: 0
# Das EFX
# 0_Check Yo Self.npy
# Rap
#
# Topic: 1
# Armando
# 0_Robotics.npy
# Electronic
# Topic: 2
# Armando
# 0_Robotics.npy
# Electronic
#
# Topic: 3
# Armando
# 0_Robotics.npy
# Electronic
#
# Topic: 4
# Vibro Champs
# 0_Martian Trip.npy
# Pop/Rock
#
# Topic: 5
# Peter Laughner
# 0_Amphetamine.npy
# Pop/Rock
#
# Topic: 6
# Mike Stern
# 0_King of the Lobby.npy
# Jazz
#
# Topic: 7
# Kid Frost
# 0_Rap Declares War.npy
# Rap
#
# Topic: 8
# Armando
# 0_Robotics.npy
# Electronic
#
# Topic: 9
# Lunachicks
# 0_Superstrong.npy
# Pop/Rock
#
# 1996 : 360 songs
# ===============================
# Topic: 0
# Rampage
# 0_Flava in Ya Ear.npy
# Rap
#
# Topic: 1
# Bushwick Bill
# 0_Stranded on Death Row.npy
# Rap
#
# Topic: 2
# Tracy Byrd
# 0_Watermelon Crawl.npy
# Country
#
# Topic: 3
# Mother Earth
# 0_Jesse.npy
# Electronic
#
# Topic: 4
# Dinah Washington
# 0_Embraceable You.npy
# Vocal
#
# Topic: 5
# Mother Earth
# 0_Jesse.npy
# Electronic
#
# Topic: 6
# Wayman Tisdale
# 0_You.npy
# Jazz
#
# Topic: 7
# Margaret Cho
# 0_[Untitled].npy
# Comedy/Spoken
#
# Topic: 8
# Jon Secada
# 0_The Best Is Yet to Come.npy
# R&B;
#
# Topic: 9
# Thee Headcoatees
# 0_Gotta Get The First Plane Home.npy
# Pop/Rock
#
# 1997 : 361 songs
# ===============================
# Topic: 0
# MC Lyte
# 0_Cold Rock a Party.npy
# Rap
#
# Topic: 1
# Eels
# 0_Novocaine for the Soul.npy
# Pop/Rock
#
# Topic: 2
# Zap Pow
# 0_Small Axe.npy
# Reggae
#
# Topic: 3
# Chavela Vargas
# 0_Luz de Luna.npy
# Latin
#
# Topic: 4
# Spookey Ruben
# 0_These Days Are Old.npy
# Pop/Rock
#
# Topic: 5
# Geggy Tah
# 0_Whoever You Are.npy
# Pop/Rock
#
# Topic: 6
# Coyle & Sharpe
# 0_Vocal Projection.npy
# Comedy/Spoken
#
# Topic: 7
# Jayne County
# 0_Help the Homeless.npy
# Pop/Rock
#
# Topic: 8
# MC Lyte
# 0_Cold Rock a Party.npy
# Rap
#
# Topic: 9
# Shelter
# 0_Here We Go.npy
# Pop/Rock
#
# 1998 : 431 songs
# ===============================
# Topic: 0
# Barry Adamson
# 0_The Sweetest Embrace.npy
# Pop/Rock
#
# Topic: 1
# Leah Andreone
# 0_I Feel the Earth Move.npy
# Pop/Rock
#
# Topic: 2
# Black Grape
# 0_England's Irie.npy
# Pop/Rock
#
# Topic: 3
# HammerFall
# 0_Stone Cold.npy
# Pop/Rock
#
# Topic: 4
# Nando Boom
# 0_So Things Ah Go.npy
# Latin
#
# Topic: 5
# Barry Adamson
# 0_The Sweetest Embrace.npy
# Pop/Rock
#
# Topic: 6
# Kirk Whalum
# 0_Kickin' Back.npy
# Jazz
#
# Topic: 7
# Scientist
# 0_Miss Know It All.npy
# Reggae
#
# Topic: 8
# Schoolhouse Rock
# 0_Three Is a Magic Number.npy
# Children's
#
# Topic: 9
# Butthole Surfers
# 0_Pepper.npy
# Pop/Rock
#
# 1999 : 361 songs
# ===============================
# Topic: 0
# King Radio
# 0_DC-10.npy
# International
#
# Topic: 1
# ATB
# 0_9 P.M. (Till I Come).npy
# Electronic
#
# Topic: 2
# ATB
# 0_9 P.M. (Till I Come).npy
# Electronic
#
# Topic: 3
# Stoney Edwards
# 0_Don't Be Angry.npy
# Country
#
# Topic: 4
# R. Kelly
# 0_Be Careful.npy
# R&B;
#
# Topic: 5
# Baxter
# 0_Television.npy
# Pop/Rock
#
# Topic: 6
# Silkk the Shocker
# 0_I Miss My Homies.npy
# Rap
#
# Topic: 7
# ATB
# 0_9 P.M. (Till I Come).npy
# Electronic
#
# Topic: 8
# Skanatra
# 0_That's Life.npy
# Pop/Rock
#
# Topic: 9
# King Radio
# 0_DC-10.npy
# International
#
# 2000 : 382 songs
# ===============================
# Topic: 0
# Jesse Powell
# 0_Tears on My Pillow.npy
# R&B;
#
# Topic: 1
# Static-X
# 0_Push It.npy
# Pop/Rock
#
# Topic: 2
# Quannum
# 0_Divine Intervention.npy
# Rap
#
# Topic: 3
# Rahsaan Patterson
# 0_Tears on My Pillow.npy
# R&B;
#
# Topic: 4
# Michael Krassner
# 0_You're Such a Fool.npy
# Country
#
# Topic: 5
# Keith Harling
# 0_Santa's Got a Semi.npy
# Country
#
# Topic: 6
# Nitin Sawhney
# 0_Homelands.npy
# Electronic
#
# Topic: 7
# Herbert
# 0_The Last Beat.npy
# Electronic
#
# Topic: 8
# The Ladybug Transistor
# 0_Puis-Je?.npy
# Pop/Rock
#
# Topic: 9
# Hate Dept.
# 0_Effigy.npy
# Pop/Rock
#
# 2001 : 410 songs
# ===============================
# Topic: 0
# Lucy Pearl
# 0_You.npy
# R&B;
#
# Topic: 1
# Tom Araya
# 0_Terrorist.npy
# Pop/Rock
#
# Topic: 2
# Captain Beefheart
# 0_Bat Chain Puller.npy
# Pop/Rock
#
# Topic: 3
# Oxide & Neutrino
# 0_Bound 4 da Reload.npy
# Electronic
#
# Topic: 4
# Mr. Scruff
# 0_Get a Move On.npy
# Electronic
#
# Topic: 5
# Otis Clay
# 0_The Weight.npy
# R&B;
#
# Topic: 6
# Mr. Len
# 0_Protective Custody.npy
# Rap
#
# Topic: 7
# Front Line Assembly
# 0_New Year's Day.npy
# Pop/Rock
#
# Topic: 8
# RatDog
# 0_Take Me to the River.npy
# Pop/Rock
#
# Topic: 9
# Lucy Pearl
# 0_You.npy
# R&B;
#
# 2002 : 407 songs
# ===============================
# Topic: 0
# Groove Collective
# 0_Stargazer.npy
# R&B;
#
# Topic: 1
# Si*Sé
# 0_The Rain (Where Do I Begin?).npy
# Electronic
#
# Topic: 2
# Big Bill Morganfield
# 0_You're Gonna Miss Me.npy
# Blues
#
# Topic: 3
# Afroman
# 0_Because I Got High.npy
# Rap
#
# Topic: 4
# Samantha Mumba
# 0_Gotta Tell You.npy
# Pop/Rock
#
# Topic: 5
# Samantha Mumba
# 0_Gotta Tell You.npy
# Pop/Rock
#
# Topic: 6
# Mount Florida
# 0_Don't Do Dada.npy
# Electronic
#
# Topic: 7
# Groove Collective
# 0_Stargazer.npy
# R&B;
#
# Topic: 8
# Hadacol
# 0_Gerald Ford.npy
# Pop/Rock
#
# Topic: 9
# Stabbing Westward
# 0_So Far Away.npy
# Pop/Rock
#
# 2003 : 444 songs
# ===============================
# Topic: 0
# RZA
# 0_Wu-Gambinos.npy
# Rap
#
# Topic: 1
# Kit Clayton
# 0_0-1.npy
# Electronic
#
# Topic: 2
# Kit Clayton
# 0_0-1.npy
# Electronic
#
# Topic: 3
# Van Hunt
# 0_Something to Believe In.npy
# R&B;
#
# Topic: 4
# Morgan Geist
# 0_Ghost Trains.npy
# Electronic
#
# Topic: 5
# Van Hunt
# 0_Something to Believe In.npy
# R&B;
#
# Topic: 6
# Morgan Geist
# 0_Ghost Trains.npy
# Electronic
#
# Topic: 7
# Kit Clayton
# 0_0-1.npy
# Electronic
#
# Topic: 8
# Kit Clayton
# 0_0-1.npy
# Electronic
#
# Topic: 9
# Death Threat
# 0_As One We Stand.npy
# Pop/Rock
#
# 2004 : 440 songs
# ===============================
# Topic: 0
# EMF
# 0_Accidents Will Happen.npy
# Pop/Rock
#
# Topic: 1
# Sense Field
# 0_On Your Own.npy
# Pop/Rock
#
# Topic: 2
# Chalee Tennison
# 0_I Am Love.npy
# Country
#
# Topic: 3
# Chicken Lips
# 0_He Not In.npy
# Electronic
#
# Topic: 4
# Sizzla
# 0_The Crown.npy
# Reggae
#
# Topic: 5
# Blueprint
# 0_Final Frontier.npy
# Rap
#
# Topic: 6
# Dannii Minogue
# 0_I Begin to Wonder.npy
# Pop/Rock
#
# Topic: 7
# DarkRoom Familia
# 0_Funk on Sight.npy
# Rap
#
# Topic: 8
# Jurassic 5
# 0_Thin Line.npy
# Rap
#
# Topic: 9
# EMF
# 0_Accidents Will Happen.npy
# Pop/Rock
#
# 2005 : 407 songs
# ===============================
# Topic: 0
# Bettye Swann
# 0_Today I Started Loving You Again.npy
# R&B;
#
# Topic: 1
# The Subdudes
# 0_The Rain.npy
# Pop/Rock
#
# Topic: 2
# Sylvia Striplin
# 0_You Can't Turn Me Away.npy
# R&B;
#
# Topic: 3
# Money Mark
# 0_Butternut.npy
# Pop/Rock
#
# Topic: 4
# Charlie Wilson
# 0_Signs.npy
# R&B;
#
# Topic: 5
# Sylvia Striplin
# 0_You Can't Turn Me Away.npy
# R&B;
#
# Topic: 6
# Charlie Wilson
# 0_Signs.npy
# R&B;
#
# Topic: 7
# Charlie Wilson
# 0_Signs.npy
# R&B;
#
# Topic: 8
# Charlie Wilson
# 0_Signs.npy
# R&B;
#
# Topic: 9
# Bévinda
# 0_Mulher Passaro.npy
# Latin
#
# 2006 : 420 songs
# ===============================
# Topic: 0
# Indigo Girls
# 0_Rock and Roll Heaven's Gate.npy
# Pop/Rock
#
# Topic: 1
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 2
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 3
# K.K. Null
# 0_Kosmista Noisea I.npy
# Pop/Rock
#
# Topic: 4
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 5
# The Cheetah Girls
# 0_The Party's Just Begun.npy
# Pop/Rock
#
# Topic: 6
# Shaun Ryder
# 0_DARE.npy
# Pop/Rock
#
# Topic: 7
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 8
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 9
# Indigo Girls
# 0_Rock and Roll Heaven's Gate.npy
# Pop/Rock
#
# 2007 : 406 songs
# ===============================
# Topic: 0
# Charmaine Neville
# 0_With You in Mind.npy
# Jazz
#
# Topic: 1
# Two Gallants
# 0_Steady Rollin'.npy
# Pop/Rock
#
# Topic: 2
# Lyfe Jennings
# 0_We Are Family.npy
# R&B;
#
# Topic: 3
# Jose Conde y Ola Fresca
# 0_Pititi y Titi.npy
# International
#
# Topic: 4
# 2face Idibia
# 0_African Queen.npy
# International
#
# Topic: 5
# Charmaine Neville
# 0_With You in Mind.npy
# Jazz
#
# Topic: 6
# Thighpaulsandra
# 0_Star Malloy.npy
# Pop/Rock
#
# Topic: 7
# Leiber & Stoller
# 0_Shake 'Em Up & Let 'Em Roll.npy
# Pop/Rock
#
# Topic: 8
# 2face Idibia
# 0_African Queen.npy
# International
#
# Topic: 9
# Matt Nathanson
# 0_Come on Get Higher.npy
# Pop/Rock
#
# 2008 : 410 songs
# ===============================
# Topic: 0
# Alvin & the Chipmunks
# 0_The Chipmunk Song (Christmas Don't Be Late).npy
# Children's
#
# Topic: 1
# Made Out of Babies
# 0_Invisible Ink.npy
# Pop/Rock
#
# Topic: 2
# Supermayer
# 0_Two of Us.npy
# Electronic
#
# Topic: 3
# Kleeer
# 0_Tonight.npy
# R&B;
#
# Topic: 4
# Supermayer
# 0_Two of Us.npy
# Electronic
#
# Topic: 5
# Ashford & Simpson
# 0_Found a Cure.npy
# R&B;
#
# Topic: 6
# Geoff Zanelli
# 0_He's A Pirate [Tiesto Remix].npy
# Stage & Screen
#
# Topic: 7
# Vic Juris
# 0_Black Satin.npy
# Jazz
#
# Topic: 8
# Ashford & Simpson
# 0_Found a Cure.npy
# R&B;
#
# Topic: 9
# Marc Broussard
# 0_Nothing Wrong.npy
# Pop/Rock
#
# 2009 : 318 songs
# ===============================
# Topic: 0
# Mayo Thompson
# 0_The Lesson.npy
# Pop/Rock
#
# Topic: 1
# Kate Voegele
# 0_I Get It.npy
# Pop/Rock
#
# Topic: 2
# The Answer
# 0_Never Too Late.npy
# Pop/Rock
#
# Topic: 3
# Michna
# 0_Redline Flights.npy
# Electronic
#
# Topic: 4
# Andrew Tosh
# 0_I'm the Tuffest.npy
# Reggae
#
# Topic: 5
# Mason Proper
# 0_Miss Marylou Carreau.npy
# Pop/Rock
#
# Topic: 6
# Mason Proper
# 0_Miss Marylou Carreau.npy
# Pop/Rock
#
# Topic: 7
# Andrew Tosh
# 0_I'm the Tuffest.npy
# Reggae
#
# Topic: 8
# Bernie Mac
# 0_I'm Your Puppet.npy
# Stage & Screen
#
# Topic: 9
# Blaq Poet
# 0_Don't Give a Fuccc.npy
# Rap
#
# 2010 : 350 songs
# ===============================
# Topic: 0
# Playdoe
# 0_Game.npy
# Rap
#
# Topic: 1
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# Topic: 2
# Chantal Kreviazuk
# 0_Half of Me.npy
# Easy Listening
#
# Topic: 3
# Thirty Seconds to Mars
# 0_Kings and Queens.npy
# Pop/Rock
#
# Topic: 4
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# Topic: 5
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# Topic: 6
# Chantal Kreviazuk
# 0_Half of Me.npy
# Easy Listening
#
# Topic: 7
# Nick Jonas & the Administration
# 0_Who I Am.npy
# Pop/Rock
#
# Topic: 8
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# Topic: 9
# Solex
# 0_The Uppercut.npy
# Electronic
#
# 2011 : 272 songs
# ===============================
# Topic: 0
# Beth McKee
# 0_Not Tonight, Josephine.npy
# R&B;
#
# Topic: 1
# Fun.
# 0_We Are Young.npy
# Pop/Rock
#
# Topic: 2
# The Minus 5
# 0_View from Below.npy
# Pop/Rock
#
# Topic: 3
# Hugh Le Caine
# 0_Concertando Rubato.npy
# Avant-Garde
#
# Topic: 4
# Sarah Silverman
# 0_Blind Woman Blues.npy
# Comedy/Spoken
#
# Topic: 5
# Lee Ritenour
# 0_My One and Only Love.npy
# Jazz
#
# Topic: 6
# Adrian Sherwood
# 0_His Master's Voice.npy
# Pop/Rock
#
# Topic: 7
# Los Tigres del Norte
# 0_Jefe De Jefes.npy
# Latin
#
# Topic: 8
# Beth McKee
# 0_Not Tonight, Josephine.npy
# R&B;
#
# Topic: 9
# Shemekia Copeland
# 0_Baby Don't Do It.npy
# Blues
#
# 2012 : 299 songs
# ===============================
# Topic: 0
# Suburban Legends
# 0_Powerful Game.npy
# Pop/Rock
#
# Topic: 1
# Jason Aldean
# 0_Say You, Say Me.npy
# Country
#
# Topic: 2
# J Dilla
# 0_E=MC2.npy
# Rap
#
# Topic: 3
# Milosh
# 0_Tailor-Made.npy
# Pop/Rock
#
# Topic: 4
# Dispatch
# 0_Bang Bang.npy
# Pop/Rock
#
# Topic: 5
# Sutton Foster
# 0_Friendship.npy
# Stage & Screen
#
# Topic: 6
# Frankie Lee
# 0_Bring It on Home to Me.npy
# Blues
#
# Topic: 7
# 2 Chainz
# 0_Yuck!.npy
# Rap
#
# Topic: 8
# J Dilla
# 0_E=MC2.npy
# Rap
#
# Topic: 9
# J Dilla
# 0_E=MC2.npy
# Rap
#
# 2013 : 377 songs
# ===============================
# Topic: 0
# Liza Minnelli
# 0_I've Got the World on a String.npy
# Vocal
#
# Topic: 1
# Arctic Monkeys
# 0_Do I Wanna Know?.npy
# Pop/Rock
#
# Topic: 2
# Eminem
# 0_The Monster.npy
# Rap
#
# Topic: 3
# Hannah Cohen
# 0_Renata.npy
# Pop/Rock
#
# Topic: 4
# Liza Minnelli
# 0_I've Got the World on a String.npy
# Vocal
#
# Topic: 5
# Liza Minnelli
# 0_I've Got the World on a String.npy
# Vocal
# Topic: 6
# Prefab Sprout
# 0_Devil Came a Calling.npy
# Pop/Rock
#
# Topic: 7
# Lorn
# 0_Chhurch.npy
# Electronic
#
# Topic: 8
# Mel Lewis Orchestra
# 0_Trouble in Mind.npy
# Jazz
#
# Topic: 9
# Carl Thomas
# 0_One Name.npy
# R&B;
#
# 2014 : 390 songs
# ===============================
# Topic: 0
# DJ Quik
# 0_Shine.npy
# Rap
#
# Topic: 1
# July Talk
# 0_Paper Girl.npy
# Pop/Rock
#
# Topic: 2
# Nels Cline
# 0_Lotus.npy
# Jazz
#
# Topic: 3
# Kay Starr
# 0_(Everybody's Waitin' For) The Man With the Bag.npy
# Vocal
#
# Topic: 4
# Copeland
# 0_Pin Your Wings.npy
# Pop/Rock
#
# Topic: 5
# Kay Starr
# 0_(Everybody's Waitin' For) The Man With the Bag.npy
# Vocal
#
# Topic: 6
# Lord RAJA
# 0_Gottfried Semper.npy
# Electronic
#
# Topic: 7
# Shift K3Y
# 0_Make It Good.npy
# Electronic
#
# Topic: 8
# Anderson Paak
# 0_Stand For Something.npy
# R&B;
#
# Topic: 9
# DJ Quik
# 0_Shine.npy
# Rap
#
# 2015 : 277 songs
# ===============================
# Topic: 0
# Micah P. Hinson
# 0_Beneath the Rose.npy
# Pop/Rock
#
# Topic: 1
# Joe Hertler & the Rainbow Seekers
# 0_King is Dead.npy
# Pop/Rock
#
# Topic: 2
# Tigercats
# 0_Junior Champion.npy
# Pop/Rock
#
# Topic: 3
# The Internet
# 0_Girl.npy
# R&B;
#
# Topic: 4
# Meghan Trainor
# 0_All About That Bass [Radio Disney Version].npy
# Pop/Rock
#
# Topic: 5
# Dornik
# 0_Something About You.npy
# R&B;
#
# Topic: 6
# Lil Bibby
# 0_Models & Bottles.npy
# Rap
#
# Topic: 7
# Joe Hertler & the Rainbow Seekers
# 0_King is Dead.npy
# Pop/Rock
#
# Topic: 8
# Walter Hyatt
# 0_Motor City Man.npy
# Country
#
# Topic: 9
# Mandy Moore
# 0_When Will My Life Begin.npy
# Pop/Rock
#
# 2016 : 264 songs
# ===============================
# Topic: 0
# Yonder Mountain String Band
# 0_Ripple.npy
# Country
#
# Topic: 1
# The Cadillac Three
# 0_White Lightning.npy
# Country
#
# Topic: 2
# Eddie Bo
# 0_St. James Infirmary.npy
# R&B;
#
# Topic: 3
# Eddie Bo
# 0_St. James Infirmary.npy
# R&B;
#
# Topic: 4
# The Knocks
# 0_I Wish (My Taylor Swift).npy
# Pop/Rock
#
# Topic: 5
# The Cactus Blossoms
# 0_Mississippi.npy
# Country
#
# Topic: 6
# Knxwledge
# 0_Suede.npy
# Rap
#
# Topic: 7
# Twenty One Pilots
# 0_Stressed Out.npy
# Pop/Rock
#
# Topic: 8
# Knxwledge
# 0_Suede.npy
# Rap
#
# Topic: 9
# Lil B
# 0_Flash on These Bitches.npy
# Rap
#
# 2017 : 188 songs
# ===============================
# Topic: 0
# Dan Hicks & His Hot Licks
# 0_Strike It While It's Hot.npy
# Pop/Rock
#
# Topic: 1
# ORB
# 0_Hazelwart.npy
# Pop/Rock
#
# Topic: 2
# The Frightnrs
# 0_Nothing More to Say.npy
# Pop/Rock
#
# Topic: 3
# Michael Hurley
# 0_Sweet Lucy.npy
# Folk
#
# Topic: 4
# Starrah
# 0_Imperfections.npy
# R&B;
#
# Topic: 5
# Charlotte OC
# 0_Darkest Hour.npy
# Pop/Rock
#
# Topic: 6
# Ruth B
# 0_I Was Married.npy
# Pop/Rock
#
# Topic: 7
# Alan Wilson
# 0_Pulling Hair Blues.npy
# Pop/Rock
#
# Topic: 8
# The Big Bopper
# 0_Take the "a" Train.npy
# Pop/Rock
#
# Topic: 9
# Betty Davis
# 0_Anti Love Song.npy
# R&B;
#
# 2018 : 3 songs
# ===============================
# Topic: 0
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 1
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 2
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 3
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 4
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 5
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 6
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 7
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 8
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 9
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock

# %% [markdown]
# # Correlation with AllMusic Influence Graph Degree

# %%
# Calculate max DIM influence per artist
max_dim_influences = np.array(song_topic_inf_matrix).max(axis=1)

# Get list of artist outdegrees in same order
artist_ids_ordered = [t[0] for t in bow_path_by_artist]
outdegrees_ordered = []

for id in artist_ids_ordered:
    outdegrees_ordered.append(artists[artists['id'] == id]['outdegree'].iloc[0])

# %%
# Calculate max DIM influence per artist
max_dim_influences = np.array(song_topic_inf_matrix).max(axis=1)
artist_ids_ordered = [t[0] for t in bow_path_by_artist]
unique_artist_ids = np.unique([t[0] for t in bow_path_by_artist])

max_influences_by_artist = OrderedDict()
avg_max_influences_by_artist = OrderedDict()

for id in unique_artist_ids:
    max_influences_by_artist[id] = []

for id, inf in zip(artist_ids_ordered, max_dim_influences):
    max_influences_by_artist[id].append(inf)

for id in unique_artist_ids:
    avg_max_influences_by_artist[id] = np.mean(max_influences_by_artist[id])

outdegrees_ordered = []

for id in unique_artist_ids:
    outdegrees_ordered.append(artists[artists['id'] == id]['outdegree'].iloc[0])

# %%
# Calculate correlation
spearmanr(avg_max_influences_by_artist.values(), outdegrees_ordered)
# Out:
# SpearmanrResult(correlation=0.056398945617498877, pvalue=6.5418264055223765e-11)

# %% [markdown]
# # TODO: Baseline

# %% [markdown]
# # TODO: Breakdown by Genre
