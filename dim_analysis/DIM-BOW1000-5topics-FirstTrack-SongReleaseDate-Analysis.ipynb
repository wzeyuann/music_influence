# %%
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import pandas as pd
import os
from copy import copy
from collections import OrderedDict
from scipy.stats import spearmanr
from tqdm import tqdm_notebook
import pickle

# %%
MODEL_PATH = '../models/dim_bow1000_5topics_firsttrack_songreleasedate'
BOW_DIR = '../data/features/bow_1000/'

# %%
# Load model
dim_model = DtmModel.load(MODEL_PATH)

# %%
# Load artist info
artists = pd.read_csv('../data/allmusic/artists_cleaned.csv')

# %%
# Load song info
songs = pd.read_csv('../data/artist_song_list_years_cleaned.csv')

# %%
# Load bow_path_by_artist
bow_path_by_artist = pickle.load(open('../models/bow500_path_by_artist.pk', 'rb'))

# %%
bow_path_by_artist_new = []

for (id, path, year) in bow_path_by_artist:
    bow_path_by_artist_new.append((id, BOW_DIR + path.split('/n/regal/rush_lab/xue/bow_500/')[1], year))

bow_path_by_artist = bow_path_by_artist_new

# %%
# # Add a column with a ".npy" extension
# songs['name_ext'] = songs['name_no_ext'].apply(lambda x: (x + '.npy')).str.decode('utf-8')

# # list of (artist_id, path, year) tuples
# bow_path_by_artist = []

# ids_in_songs = set(songs['artist_id'])

# for artist_id in tqdm_notebook(os.listdir(BOW_DIR)):
#     song_filename = os.listdir(BOW_DIR + artist_id)[0].decode('utf-8')
    
#     # Check if song year is missing or artist is missing from song df
#     if int(artist_id) in ids_in_songs and songs[songs['name_ext'] == song_filename]['year'].iloc[0] != 0:
#         # save (artist_id, path, year) tuple
#         bow_path_by_artist.append((int(artist_id), BOW_DIR + artist_id + '/', songs[songs['name_ext'] == song_filename]['year'].iloc[0]))

# print "Number of songs:", len(bow_path_by_artist)

# Order list by year
bow_path_by_artist.sort(key= lambda x: songs[songs['artist_id'] == x[0]]['year'].iloc[0])

# Create counter for number of songs for each year 
year_counter = {int(k) : 0 for k in np.unique(zip(*bow_path_by_artist)[2])}

for id, path, year in bow_path_by_artist:
    year_counter[year] += 1

# Lookup table for time_slice index v. year
time_slice_dict = {idx : year for (idx, year) in enumerate(sorted(year_counter))}
# List of counts for each time slice for DIM
time_seq = [year_counter[key] for key in sorted(year_counter.keys())]

print "Count of artists per each time slice:"
print time_seq
# Out:
# Count of artists per each time slice:
# [1, 1, 1, 1, 3, 1, 1, 1, 5, 3, 2, 2, 1, 2, 2, 1, 1, 2, 2, 5, 2, 2, 7, 2, 5, 5, 5, 6, 4, 6, 11, 15, 30, 42, 37, 64, 44, 44, 42, 52, 62, 49, 84, 73, 100, 113, 117, 112, 94, 135, 103, 133, 126, 131, 112, 141, 152, 167, 155, 156, 160, 141, 164, 171, 172, 182, 175, 194, 211, 203, 266, 272, 324, 360, 361, 431, 361, 382, 410, 407, 444, 440, 407, 420, 406, 410, 318, 350, 272, 299, 377, 390, 277, 264, 188, 3]

# %% [markdown]
# # Get most influential songs for each topic

# %%
# Create (num_songs, num_topics) array of influence scores
song_topic_inf_matrix = []

for time_idx in range(len(dim_model.time_slices)):    
    for song_idx in range(dim_model.time_slices[time_idx]):
        song_inf_by_topic = [None] * dim_model.num_topics

        for topic_idx in range(dim_model.num_topics):
            song_inf_by_topic[topic_idx] = dim_model.influences_time[time_idx][song_idx][topic_idx]
        
        song_topic_inf_matrix.append(song_inf_by_topic)

# %%
# Get the indices of the most influential songs per topic
most_inf_idx = np.array(song_topic_inf_matrix).argmax(axis=0)

for topic_no, artist_idx in enumerate(most_inf_idx):
    print "Topic:", topic_no
    # Lookup artist name
    print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
    # Lookup name of sample
    print os.listdir(bow_path_by_artist[artist_idx][1])[0]
    
    print
# Out:
# Topic: 0
# Don Chezina
# 0_Por Mi Reggae Muero.npy
#
# Topic: 1
# Big Jaz
# 0_Jigga WhatFaint.npy
#
# Topic: 2
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
#
# Topic: 3
# Sioux Falls
# 0_CopyPaste.npy
#
# Topic: 4
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy

# %% [markdown]
# # Get most influential songs per topic per epoch

# %%
song_topic_inf_by_year = []
song_topic_inf_matrix_copy = copy(song_topic_inf_matrix)

# Slice song-topic matrix into list of submatrices keyed by time slice
for time_idx, num_in_slice in enumerate(dim_model.time_slices):
    song_topic_inf_by_year.append(song_topic_inf_matrix_copy[:num_in_slice])
    del song_topic_inf_matrix_copy[:num_in_slice]

# %%
for idx, song_topic_matrix in enumerate(song_topic_inf_by_year):
    print time_slice_dict[idx], ':', time_seq[idx], 'songs'
    print "==============================="

    # Get the indices of the most influential songs per topic
    # Note: Need to adjust indexing since index resets to 0 for each new year
    most_inf_idx = np.array(song_topic_matrix).argmax(axis=0) + sum(dim_model.time_slices[:idx])

    for topic_no, artist_idx in enumerate(most_inf_idx):
        print "Topic:", topic_no
        # Lookup artist name
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['name'].iloc[0]
        # Lookup name of sample
        print os.listdir(bow_path_by_artist[artist_idx][1])[0]
        print artists[artists['id'] == bow_path_by_artist[artist_idx][0]]['main_genre'].iloc[0]
        print
# Out:
# 1912 : 1 songs
# ===============================
# Topic: 0
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 1
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 2
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 3
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# Topic: 4
# Cex
# 0_I Am SoundboyWe Started This (Acapella)Everlasting Life.npy
# Electronic
#
# 1916 : 1 songs
# ===============================
# Topic: 0
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 1
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 2
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 3
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# Topic: 4
# Sioux Falls
# 0_CopyPaste.npy
# Pop/Rock
#
# 1919 : 1 songs
# ===============================
# Topic: 0
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 1
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 2
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 3
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# Topic: 4
# Joe Morello
# 0_Blue Rondo à la Turk.npy
# Jazz
#
# 1921 : 1 songs
# ===============================
# Topic: 0
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 1
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 2
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 3
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# Topic: 4
# Stuart Duncan
# 0_Heartland [Pure CountrySoundtrack Version].npy
# Country
#
# 1923 : 3 songs
# ===============================
# Topic: 0
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 1
# Arnaldo Antunes
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 2
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 3
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# Topic: 4
# Don Chezina
# 0_Por Mi Reggae Muero.npy
# Latin
#
# 1924 : 1 songs
# ===============================
# Topic: 0
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 1
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 2
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 3
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# Topic: 4
# Arpanet
# 0_The Plum BlossomGame OverBeej-N-Dem, Pt. 2Rock SteadyNTT DocomoGalaxy.npy
# Electronic
#
# 1926 : 1 songs
# ===============================
# Topic: 0
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 1
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 2
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 3
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# Topic: 4
# Big Jaz
# 0_Jigga WhatFaint.npy
# Rap
#
# 1927 : 1 songs
# ===============================
# Topic: 0
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 1
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 2
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 3
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# Topic: 4
# Sophie Milman
# 0_(Getting Some) Fun Out of Life.npy
# Vocal
#
# 1928 : 5 songs
# ===============================
# Topic: 0
# Conjunto Bernal
# 0_Para Que Quiero un Amor.npy
# Latin
#
# Topic: 1
# Orlando "Cachaito" Lopez
# 0_¿Y Tú Que Has Hecho?.npy
# Latin
#
# Topic: 2
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# Topic: 3
# Half Japanese
# 0_After Mendelssohn (137 Years)Paint It BlackArthur's ....npy
# Pop/Rock
#
# Topic: 4
# Carlinhos Brown
# 0_Passe Em Casa.npy
# Latin
#
# 1929 : 3 songs
# ===============================
# Topic: 0
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 1
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 2
# Paul Di'Anno
# 0_Hot Legs.npy
# Pop/Rock
#
# Topic: 3
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# Topic: 4
# Clyde Stubblefield
# 0_I Don't Want Nobody to Give Me Nothin'.npy
# R&B;
#
# 1930 : 2 songs
# ===============================
# Topic: 0
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 1
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 2
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# Topic: 3
# Maurice Chevalier
# 0_I Love Paris.npy
# Vocal
#
# Topic: 4
# Keb' Mo'
# 0_Words of WonderGet Up Stand Up.npy
# Blues
#
# 1931 : 2 songs
# ===============================
# Topic: 0
# Blonde Redhead
# 0_Futurism Vs. Passéism.npy
# Pop/Rock
#
# Topic: 1
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 2
# Blonde Redhead
# 0_Futurism Vs. Passéism.npy
# Pop/Rock
#
# Topic: 3
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# Topic: 4
# Richard Greene
# 0_Mary of the Wild Moors.npy
# Country
#
# 1933 : 1 songs
# ===============================
# Topic: 0
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 1
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 2
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 3
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# Topic: 4
# Eliot Lipp
# 0_Oneknot.npy
# Electronic
#
# 1935 : 2 songs
# ===============================
# Topic: 0
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 1
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 2
# Amy Vachal
# 0_Blank Space.npy
# Pop/Rock
#
# Topic: 3
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# Topic: 4
# Hound Dog Taylor & the Houserockers
# 0_The Sun Is Shining.npy
# Blues
#
# 1937 : 2 songs
# ===============================
# Topic: 0
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 1
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 2
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 3
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# Topic: 4
# Uncle Walt's Band
# 0_Don't You Feel It Too?.npy
# Country
#
# 1938 : 1 songs
# ===============================
# Topic: 0
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 1
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 2
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 3
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# Topic: 4
# Gid Tanner
# 0_Where Did You Get That Hat.npy
# Country
#
# 1939 : 1 songs
# ===============================
# Topic: 0
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 1
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 2
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 3
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# Topic: 4
# Warm Brew
# 0_Chiefing In the Streets.npy
# Rap
#
# 1940 : 2 songs
# ===============================
# Topic: 0
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 1
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 2
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# Topic: 3
# Engelbert Humperdinck
# 0_Spanish Eyes.npy
# Vocal
#
# Topic: 4
# Doc Severinsen
# 0_American MedleyGod Bless AmericaAmerica the Beautiful.npy
# Jazz
#
# 1941 : 2 songs
# ===============================
# Topic: 0
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 1
# Sylvie Vartan
# 0_J'Ai un Problème.npy
# Pop/Rock
#
# Topic: 2
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 3
# Sister Rosetta Tharpe
# 0_Rock Me.npy
# Religious
#
# Topic: 4
# Sylvie Vartan
# 0_J'Ai un Problème.npy
# Pop/Rock
#
# 1942 : 5 songs
# ===============================
# Topic: 0
# The Barrett Sisters
# 0_I Shall Wear a Crown.npy
# Religious
#
# Topic: 1
# Electrik Red
# 0_So Good.npy
# R&B;
#
# Topic: 2
# Colin Blunstone
# 0_London's Brilliant ParadeCaroline, Goodbye.npy
# Pop/Rock
#
# Topic: 3
# Electrik Red
# 0_So Good.npy
# R&B;
#
# Topic: 4
# Papoose
# 0_Touch It [RemixFeaturing Mary J. Blige, Rah Digga, Missy Elliot, Lloyd Banks, Papoose & DMX].npy
# Rap
#
# 1943 : 2 songs
# ===============================
# Topic: 0
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 1
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 2
# Redd Kross
# 0_Cease to Exist.npy
# Pop/Rock
#
# Topic: 3
# Chico Science
# 0_Macô.npy
# Latin
#
# Topic: 4
# Chico Science
# 0_Macô.npy
# Latin
#
# 1944 : 2 songs
# ===============================
# Topic: 0
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 1
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 2
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# Topic: 3
# John Oswald
# 0_VTUntitled 1 September6 of 7GRRL Power Their Satanic ....npy
# Avant-Garde
#
# Topic: 4
# Eden Atwood
# 0_Have Yourself a Merry Little Christmas.npy
# Vocal
#
# 1945 : 7 songs
# ===============================
# Topic: 0
# Perry Blake
# 0_Graines d'Etoiles.npy
# Pop/Rock
#
# Topic: 1
# Kenny G
# 0_All the WayOne for My Baby (And One More for the Road).npy
# Jazz
#
# Topic: 2
# Kenny G
# 0_All the WayOne for My Baby (And One More for the Road).npy
# Jazz
# Topic: 3
# Allan Sherman
# 0_Hello Muddah, Hello Fadduh! (A Letter from Camp).npy
# Comedy/Spoken
#
# Topic: 4
# Perry Blake
# 0_Graines d'Etoiles.npy
# Pop/Rock
#
# 1946 : 2 songs
# ===============================
# Topic: 0
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 1
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 2
# Token Entry
# 0_Lucky Seven.npy
# Pop/Rock
#
# Topic: 3
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# Topic: 4
# Pedro Infante
# 0_Cien Años.npy
# Latin
#
# 1947 : 5 songs
# ===============================
# Topic: 0
# 2 Live Jews
# 0_The Hustle (Parody: The Herschel).npy
# Comedy/Spoken
#
# Topic: 1
# 2 Live Jews
# 0_The Hustle (Parody: The Herschel).npy
# Comedy/Spoken
#
# Topic: 2
# Moxie Raia
# 0_Follow Me.npy
# Pop/Rock
#
# Topic: 3
# Liam Clancy
# 0_Jig.npy
# International
#
# Topic: 4
# 2 Live Jews
# 0_The Hustle (Parody: The Herschel).npy
# Comedy/Spoken
#
# 1948 : 5 songs
# ===============================
# Topic: 0
# Zurdok
# 0_Estático.npy
# Latin
#
# Topic: 1
# Billy Mitchell
# 0_Long Notes Blue (Here Is Cecco Beppe).npy
# Jazz
#
# Topic: 2
# Denali
# 0_Cuz I'm Ballin.npy
# Pop/Rock
#
# Topic: 3
# Tom Jobim
# 0_Águas De Março.npy
# Latin
#
# Topic: 4
# Zurdok
# 0_Estático.npy
# Latin
#
# 1949 : 5 songs
# ===============================
# Topic: 0
# Gene Kelly
# 0_I Begged Her.npy
# Vocal
#
# Topic: 1
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 2
# North Mississippi Allstars
# 0_Blood on That Rock.npy
# Pop/Rock
#
# Topic: 3
# Eric Wood
# 0_Opus to Ecstasy.npy
# Folk
#
# Topic: 4
# Eric Wood
# 0_Opus to Ecstasy.npy
# Folk
#
# 1950 : 6 songs
# ===============================
# Topic: 0
# U-Roy
# 0_Wear You to the Ball.npy
# Reggae
#
# Topic: 1
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 2
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 3
# Cut Chemist
# 0_Luv U Better.npy
# Rap
#
# Topic: 4
# U-Roy
# 0_Wear You to the Ball.npy
# Reggae
#
# 1951 : 4 songs
# ===============================
# Topic: 0
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 1
# Rube Bloom
# 0_Sam, the Old Accordion Man.npy
# Jazz
#
# Topic: 2
# Ari Up
# 0_Chrome Optimism -[ Oxygen Part 4 Dub].npy
# Pop/Rock
#
# Topic: 3
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# Topic: 4
# David Grier
# 0_Porkchops & Applesauce.npy
# Country
#
# 1952 : 6 songs
# ===============================
# Topic: 0
# Eddie Holland
# 0_Super Woman (You Ain't No Ordinary Woman).npy
# R&B;
#
# Topic: 1
# Tommy Smith
# 0_Independency, Pt. 1.npy
# Jazz
#
# Topic: 2
# I Am the World Trade Center
# 0_Shoot You Down.npy
# Pop/Rock
#
# Topic: 3
# Philharmonie
# 0_Hannibal À Capoue (Hannibal at Capoue).npy
# Pop/Rock
#
# Topic: 4
# I Am the World Trade Center
# 0_Shoot You Down.npy
# Pop/Rock
#
# 1953 : 11 songs
# ===============================
# Topic: 0
# Dennis Coffey
# 0_Grandmaster Flash Turntable Mix "Freestyle Mix": God Made Me Funky.npy
# R&B;
#
# Topic: 1
# Bob Luman
# 0_Round One: Act NaturallyLet's Think About LivingWaterlooTie a ....npy
# Country
#
# Topic: 2
# Big L
# 0_Disciple of the Projects.npy
# Rap
#
# Topic: 3
# Big L
# 0_Disciple of the Projects.npy
# Rap
#
# Topic: 4
# Luciano
# 0_Neighbourhood Watch.npy
# Reggae
#
# 1954 : 15 songs
# ===============================
# Topic: 0
# Zen Tricksters
# 0_All Night Long Blues.npy
# Pop/Rock
#
# Topic: 1
# Winans Phase 2
# 0_This Train.npy
# Religious
#
# Topic: 2
# Kurupt
# 0_Dogg Pound Gangstaville.npy
# Rap
#
# Topic: 3
# Louis Armstrong
# 0_I'm Just a Lucky So and So.npy
# Jazz
#
# Topic: 4
# Louis Armstrong
# 0_I'm Just a Lucky So and So.npy
# Jazz
#
# 1955 : 30 songs
# ===============================
# Topic: 0
# Poncho Sanchez
# 0_Chano Pozo Medley: Tin Tin DeoMantecaGuachi Guaro.npy
# Jazz
#
# Topic: 1
# Poncho Sanchez
# 0_Chano Pozo Medley: Tin Tin DeoMantecaGuachi Guaro.npy
# Jazz
#
# Topic: 2
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 3
# Gerald Albright
# 0_Inner City Blues (Make Me Wanna Holler).npy
# Jazz
#
# Topic: 4
# JT the Bigga Figga
# 0_F*****' Is Good for U.npy
# Rap
#
# 1956 : 42 songs
# ===============================
# Topic: 0
# Venom
# 0_Land of No Pitty.npy
# Rap
#
# Topic: 1
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 2
# Steve Cole
# 0_Chopsticks.npy
# Jazz
#
# Topic: 3
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# Topic: 4
# Aventura
# 0_Elle y Yo.npy
# Latin
#
# 1957 : 37 songs
# ===============================
# Topic: 0
# The BusBoys
# 0_Right Place, Wrong Time.npy
# Pop/Rock
#
# Topic: 1
# Paulinho da Viola
# 0_Não Tenho Lágrimas.npy
# Latin
#
# Topic: 2
# Elaine Brown
# 0_Prove Your Love to Me.npy
# Pop/Rock
#
# Topic: 3
# Shawn Hook
# 0_Happy Xmas (War Is Over).npy
# Pop/Rock
#
# Topic: 4
# Paulinho da Viola
# 0_Não Tenho Lágrimas.npy
# Latin
#
# 1958 : 64 songs
# ===============================
# Topic: 0
# Jimmy Durante
# 0_I'll Do the Strutaway in My CutawayWho Will Be with You When I'm ....npy
# Vocal
#
# Topic: 1
# Saetia
# 0_[Untitled Hidden Track].npy
# Pop/Rock
#
# Topic: 2
# Karen Carpenter
# 0_KarenElla Medley.npy
# Pop/Rock
#
# Topic: 3
# Dyke & the Blazers
# 0_We Got More Soul.npy
# R&B;
#
# Topic: 4
# Saetia
# 0_[Untitled Hidden Track].npy
# Pop/Rock
#
# 1959 : 44 songs
# ===============================
# Topic: 0
# Moonshine Bandits
# 0_Mud Digger Mega Remix.npy
# Rap
#
# Topic: 1
# Stresmatic
# 0_Knockin' at the Light.npy
# Rap
#
# Topic: 2
# Stresmatic
# 0_Knockin' at the Light.npy
# Rap
#
# Topic: 3
# Allen Farnham
# 0_Invitation.npy
# Jazz
#
# Topic: 4
# Allen Farnham
# 0_Invitation.npy
# Jazz
#
# 1960 : 44 songs
# ===============================
# Topic: 0
# Hints
# 0_Foothills.npy
# Pop/Rock
#
# Topic: 1
# Oliver Morgan
# 0_Trick Bag.npy
# R&B;
#
# Topic: 2
# Chill Rob G.
# 0_PowerSign Off.npy
# Rap
#
# Topic: 3
# The Christianaires
# 0_Stand Up.npy
# Religious
#
# Topic: 4
# Chill Rob G.
# 0_PowerSign Off.npy
# Rap
#
# 1961 : 42 songs
# ===============================
# Topic: 0
# Tito Nieves
# 0_Sonámbulo.npy
# Latin
#
# Topic: 1
# Jordan Fisher
# 0_Gotta Be Me.npy
# Pop/Rock
#
# Topic: 2
# Jordan Fisher
# 0_Gotta Be Me.npy
# Pop/Rock
#
# Topic: 3
# Elaine Stritch
# 0_Don't Go to Bed with a Frown.npy
# Vocal
#
# Topic: 4
# Lonesome Sundown
# 0_My Home Is a Prison.npy
# Blues
#
# 1962 : 52 songs
# ===============================
# Topic: 0
# Brazilian Girls
# 0_Aquele Abraço.npy
# Pop/Rock
#
# Topic: 1
# Railroad Jerk
# 0_Good News.npy
# Pop/Rock
#
# Topic: 2
# Toño Rosario
# 0_Amigo Mio.npy
# Latin
#
# Topic: 3
# She & Him
# 0_On the Island.npy
# Pop/Rock
#
# Topic: 4
# Misfits
# 0_Pretentious.npy
# Pop/Rock
#
# 1963 : 62 songs
# ===============================
# Topic: 0
# Omar Pene
# 0_Saï Saï Sida (AIDS the Devil).npy
# International
#
# Topic: 1
# Charles Aznavour
# 0_J'Aime Paris au Mois de Mai.npy
# Vocal
#
# Topic: 2
# Grand Wizard Theodore
# 0_Medley.npy
# Rap
#
# Topic: 3
# Chuck Wayne
# 0_Conception.npy
# Jazz
#
# Topic: 4
# Pete Brown
# 0_Moonglow.npy
# Jazz
#
# 1964 : 49 songs
# ===============================
# Topic: 0
# Volume 10
# 0_Raised in the Hood.npy
# Rap
#
# Topic: 1
# The Artifacts
# 0_Cummin' Thru Ya Fuckin' Block [Remix].npy
# Rap
#
# Topic: 2
# Shayna Leigh
# 0_Next To Me.npy
# Pop/Rock
#
# Topic: 3
# The Artifacts
# 0_Cummin' Thru Ya Fuckin' Block [Remix].npy
# Rap
#
# Topic: 4
# Volume 10
# 0_Raised in the Hood.npy
# Rap
#
# 1965 : 84 songs
# ===============================
# Topic: 0
# Tupac Shakur
# 0_BiggieTupac Live Freestyle.npy
# Rap
#
# Topic: 1
# Martin Sexton
# 0_Revelry.npy
# Folk
#
# Topic: 2
# MC Paul Barman
# 0_Salvation Barny.npy
# Rap
#
# Topic: 3
# George Tandy, Jr.
# 0_Jaded.npy
# R&B;
#
# Topic: 4
# Tupac Shakur
# 0_BiggieTupac Live Freestyle.npy
# Rap
#
# 1966 : 73 songs
# ===============================
# Topic: 0
# Cabas
# 0_Mi Bombón.npy
# Latin
#
# Topic: 1
# Marlene VerPlanck
# 0_All in Fun.npy
# Vocal
#
# Topic: 2
# Cabas
# 0_Mi Bombón.npy
# Latin
#
# Topic: 3
# Fictionist
# 0_Right Now.npy
# Pop/Rock
#
# Topic: 4
# Bryan-Michael Cox
# 0_Throw the Smack DownCan't Give You UpThis.npy
# R&B;
#
# 1967 : 100 songs
# ===============================
# Topic: 0
# James Montgomery Band
# 0_Smokeys Barbecue.npy
# Blues
#
# Topic: 1
# Helen Forrest
# 0_I've Heard That Song Before.npy
# Vocal
#
# Topic: 2
# The Roosevelts
# 0_Don't Wanna Let You Go.npy
# Pop/Rock
#
# Topic: 3
# Walter Brown
# 0_Hootie Blues.npy
# Blues
#
# Topic: 4
# Tex Williams
# 0_Smoke! Smoke! Smoke! (That Cigarette).npy
# Country
#
# 1968 : 113 songs
# ===============================
# Topic: 0
# Johnnie Ray
# 0_Let's Walk That-A-Way.npy
# Vocal
#
# Topic: 1
# Elmo Hope
# 0_Solid.npy
# Jazz
#
# Topic: 2
# Guy Lombardo
# 0_Christmas Island.npy
# Easy Listening
#
# Topic: 3
# Léo Ferré
# 0_Paris Canaille.npy
# Vocal
#
# Topic: 4
# The Robins
# 0_Smokey Joe's Cafe.npy
# R&B;
#
# 1969 : 117 songs
# ===============================
# Topic: 0
# Jack Marshall
# 0_Fever.npy
# Jazz
#
# Topic: 1
# Jim Dandy
# 0_Jim Dandy.npy
# Pop/Rock
#
# Topic: 2
# Jim Dandy
# 0_Jim Dandy.npy
# Pop/Rock
#
# Topic: 3
# Screamin' Jay Hawkins
# 0_Little Demon.npy
# R&B;
#
# Topic: 4
# The Monotones
# 0_Book of Love.npy
# R&B;
#
# 1970 : 112 songs
# ===============================
# Topic: 0
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 1
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 2
# Sam Cooke
# 0_Chain Gang.npy
# R&B;
#
# Topic: 3
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# Topic: 4
# Cha Cha
# 0_Good Night Sweetheart.npy
# R&B;
#
# 1971 : 94 songs
# ===============================
# Topic: 0
# The Marvelettes
# 0_Playboy.npy
# R&B;
#
# Topic: 1
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# Topic: 2
# Gene Chandler
# 0_Duke of Earl.npy
# R&B;
#
# Topic: 3
# Dion
# 0_Runaround Sue.npy
# Pop/Rock
#
# Topic: 4
# Ben E. King
# 0_Spanish Harlem.npy
# R&B;
#
# 1972 : 135 songs
# ===============================
# Topic: 0
# Sandie Shaw
# 0_(There's) Always Something There to Remind Me.npy
# Pop/Rock
#
# Topic: 1
# The Angels
# 0_My Boyfriend's Back.npy
# Pop/Rock
#
# Topic: 2
# The Angels
# 0_My Boyfriend's Back.npy
# Pop/Rock
#
# Topic: 3
# The Angels
# 0_My Boyfriend's Back.npy
# Pop/Rock
#
# Topic: 4
# Sandie Shaw
# 0_(There's) Always Something There to Remind Me.npy
# Pop/Rock
#
# 1973 : 103 songs
# ===============================
# Topic: 0
# The Statler Brothers
# 0_Flowers on the Wall.npy
# Country
#
# Topic: 1
# Joe Hinton
# 0_Funny (How Time Slips Away).npy
# R&B;
#
# Topic: 2
# The Knickerbockers
# 0_Lies.npy
# Pop/Rock
#
# Topic: 3
# Gil Fuller
# 0_Be's That Way.npy
# Jazz
#
# Topic: 4
# Jon Hendricks
# 0_Fire in the City.npy
# Vocal
#
# 1974 : 133 songs
# ===============================
# Topic: 0
# Herman's Hermits
# 0_There's a Kind of Hush (All Over the World).npy
# Pop/Rock
#
# Topic: 1
# The Herd
# 0_From the Underworld.npy
# Pop/Rock
#
# Topic: 2
# Tammi Terrell
# 0_If I Could Build My Whole World Around You.npy
# R&B;
#
# Topic: 3
# O.V. Wright
# 0_Eight Men, Four Women.npy
# R&B;
#
# Topic: 4
# Ray Price
# 0_I'm Still Not over You.npy
# Country
#
# 1975 : 126 songs
# ===============================
# Topic: 0
# Rhinoceros
# 0_That Time of the Year.npy
# Pop/Rock
#
# Topic: 1
# Bobbie Gentry
# 0_All I Have to Do Is Dream.npy
# Country
#
# Topic: 2
# Buzzy Linhart
# 0_Yellow Cab.npy
# Folk
#
# Topic: 3
# Pigmeat Markham
# 0_Here Comes the Judge.npy
# Comedy/Spoken
#
# Topic: 4
# Buzzy Linhart
# 0_Yellow Cab.npy
# Folk
#
# 1976 : 131 songs
# ===============================
# Topic: 0
# El Chicano
# 0_Viva Tirado.npy
# Pop/Rock
#
# Topic: 1
# J.T. Brown
# 0_I Can't Hold Out.npy
# Blues
#
# Topic: 2
# The Wailers
# 0_Duppy Conqueror.npy
# Reggae
#
# Topic: 3
# J.T. Brown
# 0_I Can't Hold Out.npy
# Blues
#
# Topic: 4
# El Chicano
# 0_Viva Tirado.npy
# Pop/Rock
#
# 1977 : 112 songs
# ===============================
# Topic: 0
# Johnny Winter
# 0_Johnny B. Goode.npy
# Blues
#
# Topic: 1
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 2
# The Jimi Hendrix Experience
# 0_Manic Depression.npy
# Pop/Rock
#
# Topic: 3
# Shel Silverstein
# 0_A Front Row Seat to Hear Ole Johnny Sing.npy
# Folk
#
# Topic: 4
# Jethro Tull
# 0_My God.npy
# Pop/Rock
#
# 1978 : 141 songs
# ===============================
# Topic: 0
# Albert Hammond
# 0_It Never Rains in Southern California.npy
# Pop/Rock
#
# Topic: 1
# Bill Anderson
# 0_The Lord Knows I'm Drinking.npy
# Country
#
# Topic: 2
# Johnny Nash
# 0_Stir It Up.npy
# R&B;
#
# Topic: 3
# Cat Stevens
# 0_Where Do the Children Play?.npy
# Pop/Rock
#
# Topic: 4
# Red Simpson
# 0_I'm a Truck.npy
# Country
#
# 1979 : 152 songs
# ===============================
# Topic: 0
# Grand Funk Railroad
# 0_Some Kind of Wonderful.npy
# Pop/Rock
#
# Topic: 1
# The Heptones
# 0_Book of Rules.npy
# Reggae
#
# Topic: 2
# Highway 101
# 0_Young Country.npy
# Country
#
# Topic: 3
# Highway 101
# 0_Young Country.npy
# Country
#
# Topic: 4
# Ramón Ayala
# 0_Por Tus Caprichos.npy
# Latin
#
# 1980 : 167 songs
# ===============================
# Topic: 0
# Scott 4
# 0_East Winter.npy
# Pop/Rock
#
# Topic: 1
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 2
# Be Bop Deluxe
# 0_Ships in the Night.npy
# Pop/Rock
#
# Topic: 3
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# Topic: 4
# Cornell Campbell
# 0_No Good Girl.npy
# Reggae
#
# 1981 : 155 songs
# ===============================
# Topic: 0
# Dead Boys
# 0_Sonic Reducer.npy
# Pop/Rock
#
# Topic: 1
# The Brothers Johnson
# 0_Strawberry Letter 23.npy
# R&B;
#
# Topic: 2
# The Brothers Johnson
# 0_Strawberry Letter 23.npy
# R&B;
#
# Topic: 3
# Victor Feldman
# 0_Aja.npy
# Jazz
#
# Topic: 4
# George Benson
# 0_Breezin'.npy
# Jazz
#
# 1982 : 156 songs
# ===============================
# Topic: 0
# Lene Lovich
# 0_Lucky Number.npy
# Pop/Rock
#
# Topic: 1
# Herb Alpert
# 0_A Taste of Honey.npy
# Easy Listening
#
# Topic: 2
# The Osmonds
# 0_Morning Side of the Mountain.npy
# Pop/Rock
#
# Topic: 3
# Stuff
# 0_Signed, Sealed, Delivered I'm Yours.npy
# R&B;
#
# Topic: 4
# John Cooper Clarke
# 0_Readers Wives.npy
# Pop/Rock
#
# 1983 : 160 songs
# ===============================
# Topic: 0
# Ian Dury
# 0_Hit Me with Your Rhythm Stick.npy
# Pop/Rock
#
# Topic: 1
# A Taste of Honey
# 0_Boogie Oogie Oogie.npy
# R&B;
#
# Topic: 2
# Skids
# 0_Into the Valley.npy
# Pop/Rock
#
# Topic: 3
# Ronnie Laws
# 0_Always There.npy
# Jazz
#
# Topic: 4
# Stevie Wonder
# 0_One Little Christmas Tree.npy
# R&B;
#
# 1984 : 141 songs
# ===============================
# Topic: 0
# Joan Jett
# 0_Bad Reputation.npy
# Pop/Rock
#
# Topic: 1
# Shalamar
# 0_Make That Move.npy
# R&B;
#
# Topic: 2
# Graham Parker & the Rumour
# 0_Soul Shoes.npy
# Pop/Rock
#
# Topic: 3
# Shalamar
# 0_Make That Move.npy
# R&B;
#
# Topic: 4
# Shalamar
# 0_Make That Move.npy
# R&B;
#
# 1985 : 164 songs
# ===============================
# Topic: 0
# Men at Work
# 0_Who Can It Be Now?.npy
# Pop/Rock
#
# Topic: 1
# Dirk Bogarde
# 0_A Foggy Day.npy
# Vocal
#
# Topic: 2
# Urban Verbs
# 0_Acceleration.npy
# Pop/Rock
#
# Topic: 3
# Pierre Moerlen
# 0_Leave It Open.npy
# Electronic
#
# Topic: 4
# Men at Work
# 0_Who Can It Be Now?.npy
# Pop/Rock
#
# 1986 : 171 songs
# ===============================
# Topic: 0
# The Jonzun Crew
# 0_Pack Jam (Look Out for the OVC).npy
# R&B;
#
# Topic: 1
# Bill Withers
# 0_Just the Two of Us.npy
# R&B;
#
# Topic: 2
# The Jonzun Crew
# 0_Pack Jam (Look Out for the OVC).npy
# R&B;
#
# Topic: 3
# Japan
# 0_Ghosts.npy
# Pop/Rock
#
# Topic: 4
# The Jonzun Crew
# 0_Pack Jam (Look Out for the OVC).npy
# R&B;
#
# 1987 : 172 songs
# ===============================
# Topic: 0
# Newcleus
# 0_Jam on Revenge (The Wikki Wikki Song).npy
# Rap
#
# Topic: 1
# Touchdown
# 0_Ease Your Mind.npy
# Electronic
#
# Topic: 2
# Rufus
# 0_Ain't Nobody.npy
# R&B;
#
# Topic: 3
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# Topic: 4
# Odyssey
# 0_Inside Out.npy
# R&B;
#
# 1988 : 182 songs
# ===============================
# Topic: 0
# Arrow
# 0_Hot Hot Hot.npy
# International
#
# Topic: 1
# The Smurfs
# 0_Silent Night.npy
# Children's
#
# Topic: 2
# The Untouchables
# 0_Free Yourself.npy
# Electronic
#
# Topic: 3
# K. Michelle
# 0_Ride Out.npy
# R&B;
#
# Topic: 4
# The Real Roxanne
# 0_The Real Roxanne.npy
# Rap
#
# 1989 : 175 songs
# ===============================
# Topic: 0
# Carlene Davis
# 0_Bits and Pieces.npy
# Reggae
#
# Topic: 1
# Carlene Davis
# 0_Bits and Pieces.npy
# Reggae
#
# Topic: 2
# Grandmaster Melle Mel
# 0_Let Me See Your I.D..npy
# Rap
#
# Topic: 3
# Dallas Holm
# 0_Rise Again.npy
# Religious
#
# Topic: 4
# Carlene Davis
# 0_Bits and Pieces.npy
# Reggae
#
# 1990 : 194 songs
# ===============================
# Topic: 0
# Larry Graham
# 0_If You Need My Love Tonight.npy
# R&B;
#
# Topic: 1
# Annie Ross
# 0_Twisted.npy
# Vocal
#
# Topic: 2
# Kenny Loggins
# 0_Danger Zone.npy
# Pop/Rock
#
# Topic: 3
# Lonnie Brooks
# 0_Got Lucky Last Night.npy
# Blues
#
# Topic: 4
# The Controllers
# 0_Got a Thang.npy
# R&B;
#
# 1991 : 211 songs
# ===============================
# Topic: 0
# Dynamix II
# 0_Just Give the DJ a Break.npy
# Electronic
#
# Topic: 1
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 2
# The Deele
# 0_Two Occasions.npy
# R&B;
#
# Topic: 3
# Carlos Santana
# 0_Gypsy Woman.npy
# Pop/Rock
#
# Topic: 4
# Atlantic Starr
# 0_Always.npy
# R&B;
#
# 1992 : 203 songs
# ===============================
# Topic: 0
# Junkyard
# 0_Hollywood.npy
# Pop/Rock
#
# Topic: 1
# Bobby McFerrin
# 0_Don't Worry Be Happy.npy
# Vocal
#
# Topic: 2
# Skid Row
# 0_18 and Life.npy
# Pop/Rock
#
# Topic: 3
# Will Downing
# 0_A Love Supreme.npy
# R&B;
#
# Topic: 4
# Aster Aweke
# 0_Tizita (Memories).npy
# International
#
# 1993 : 266 songs
# ===============================
# Topic: 0
# Tackhead
# 0_Repetition.npy
# Pop/Rock
#
# Topic: 1
# Dave Hole
# 0_Short Fuse Blues.npy
# Blues
#
# Topic: 2
# Ricardo Montaner
# 0_Cima del Cielo.npy
# Latin
#
# Topic: 3
# Adamski
# 0_Killer.npy
# Electronic
#
# Topic: 4
# Swampwater
# 0_Freeborn Man.npy
# Pop/Rock
#
# 1994 : 272 songs
# ===============================
# Topic: 0
# Lee Allen
# 0_Everyday I Have the Blues.npy
# R&B;
#
# Topic: 1
# The Tinklers
# 0_Trees Like to Rot in the Forest.npy
# Pop/Rock
#
# Topic: 2
# Joe Satriani
# 0_Hey Stoopid.npy
# Pop/Rock
#
# Topic: 3
# Mark Chesnutt
# 0_Bubba Shot the Jukebox.npy
# Country
#
# Topic: 4
# Macka B
# 0_Mister Cop.npy
# Reggae
#
# 1995 : 324 songs
# ===============================
# Topic: 0
# Flop
# 0_Hello.npy
# Pop/Rock
#
# Topic: 1
# Armando
# 0_Robotics.npy
# Electronic
#
# Topic: 2
# Green Jelly
# 0_Three Little Pigs.npy
# Pop/Rock
#
# Topic: 3
# Stella
# 0_Friends.npy
# R&B;
#
# Topic: 4
# A.G.
# 0_2K007.npy
# Rap
#
# 1996 : 360 songs
# ===============================
# Topic: 0
# Thee Headcoatees
# 0_Gotta Get The First Plane Home.npy
# Pop/Rock
#
# Topic: 1
# Hank Crawford
# 0_Hank's Groove.npy
# Jazz
#
# Topic: 2
# Dark Funeral
# 0_My Dark Desires.npy
# Pop/Rock
#
# Topic: 3
# Jon Secada
# 0_The Best Is Yet to Come.npy
# R&B;
#
# Topic: 4
# Rob Wasserman
# 0_Put Your Big Toe in the Milk of Human Kindness.npy
# Jazz
#
# 1997 : 361 songs
# ===============================
# Topic: 0
# Long Fin Killie
# 0_The Heads of Dead Surfers.npy
# Pop/Rock
#
# Topic: 1
# Palace
# 0_The Brute Choir.npy
# Pop/Rock
#
# Topic: 2
# Deep Blue Something
# 0_Breakfast at Tiffany's.npy
# Pop/Rock
#
# Topic: 3
# Al Di Meola
# 0_Hymn Of The Seventh Galaxy.npy
# Jazz
#
# Topic: 4
# David Friedman
# 0_Lunch With Pancho Villa.npy
# Jazz
#
# 1998 : 431 songs
# ===============================
# Topic: 0
# Diana King
# 0_When We Were Kings.npy
# Reggae
#
# Topic: 1
# Barry Adamson
# 0_The Sweetest Embrace.npy
# Pop/Rock
#
# Topic: 2
# Speedy J
# 0_Patterns.npy
# Electronic
#
# Topic: 3
# Kirk Whalum
# 0_Kickin' Back.npy
# Jazz
#
# Topic: 4
# Barry Adamson
# 0_The Sweetest Embrace.npy
# Pop/Rock
#
# 1999 : 361 songs
# ===============================
# Topic: 0
# All City
# 0_Xtreme.npy
# Rap
#
# Topic: 1
# Scott Henderson
# 0_Snake Soda.npy
# Jazz
#
# Topic: 2
# Geezer Butler
# 0_Man in a Suitcase.npy
# Pop/Rock
#
# Topic: 3
# ATB
# 0_9 P.M. (Till I Come).npy
# Electronic
#
# Topic: 4
# Boilermaker
# 0_Last on the Drive.npy
# Pop/Rock
#
# 2000 : 382 songs
# ===============================
# Topic: 0
# Fu Manchu
# 0_Mongoose.npy
# Pop/Rock
# Topic: 1
# Rahsaan Patterson
# 0_Tears on My Pillow.npy
# R&B;
#
# Topic: 2
# Static-X
# 0_Push It.npy
# Pop/Rock
#
# Topic: 3
# Nitin Sawhney
# 0_Homelands.npy
# Electronic
#
# Topic: 4
# Jesse Powell
# 0_Tears on My Pillow.npy
# R&B;
#
# 2001 : 410 songs
# ===============================
# Topic: 0
# Admiral Bailey
# 0_Punanny Medley.npy
# Reggae
#
# Topic: 1
# Otis Clay
# 0_The Weight.npy
# R&B;
#
# Topic: 2
# Front Line Assembly
# 0_New Year's Day.npy
# Pop/Rock
#
# Topic: 3
# Tevin Campbell
# 0_Everything.npy
# R&B;
#
# Topic: 4
# Lucy Pearl
# 0_You.npy
# R&B;
#
# 2002 : 407 songs
# ===============================
# Topic: 0
# The Presidents of the United States of America
# 0_Nuthin But Luv.npy
# Pop/Rock
#
# Topic: 1
# Groove Collective
# 0_Stargazer.npy
# R&B;
#
# Topic: 2
# Army of Freshmen
# 0_Adeline.npy
# Pop/Rock
#
# Topic: 3
# Big Bill Morganfield
# 0_You're Gonna Miss Me.npy
# Blues
#
# Topic: 4
# Groove Collective
# 0_Stargazer.npy
# R&B;
#
# 2003 : 444 songs
# ===============================
# Topic: 0
# Ruins
# 0_Fredmans Session 2.npy
# Pop/Rock
#
# Topic: 1
# Morgan Geist
# 0_Ghost Trains.npy
# Electronic
#
# Topic: 2
# Paul Gilbert
# 0_Let the Computer Decide.npy
# Pop/Rock
#
# Topic: 3
# Morgan Geist
# 0_Ghost Trains.npy
# Electronic
#
# Topic: 4
# Justin Adams
# 0_Win My Train Fare Home (If I Ever Get Lucky).npy
# R&B;
#
# 2004 : 440 songs
# ===============================
# Topic: 0
# Lyrics Born
# 0_Emerge.npy
# Rap
#
# Topic: 1
# Stacie Orrico
# 0_(There's Gotta Be) More to Life.npy
# Religious
#
# Topic: 2
# Cold
# 0_Stupid Girl.npy
# Pop/Rock
#
# Topic: 3
# Pépé Bradock
# 0_4.npy
# Electronic
#
# Topic: 4
# Nivea
# 0_Ya Ya Ya.npy
# R&B;
#
# 2005 : 407 songs
# ===============================
# Topic: 0
# Sodom
# 0_Nuclear Winter.npy
# Pop/Rock
#
# Topic: 1
# David "Honeyboy" Edwards
# 0_Crossroads.npy
# Blues
#
# Topic: 2
# None More Black
# 0_Nothing to Do When You're Locked in a Vacancy.npy
# Pop/Rock
#
# Topic: 3
# Jay-Jay Johanson
# 0_Because of You.npy
# Electronic
#
# Topic: 4
# Bévinda
# 0_Mulher Passaro.npy
# Latin
#
# 2006 : 420 songs
# ===============================
# Topic: 0
# Indigo Girls
# 0_Rock and Roll Heaven's Gate.npy
# Pop/Rock
#
# Topic: 1
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 2
# Burning Spear
# 0_Slavery Days.npy
# Reggae
#
# Topic: 3
# K.K. Null
# 0_Kosmista Noisea I.npy
# Pop/Rock
#
# Topic: 4
# Indigo Girls
# 0_Rock and Roll Heaven's Gate.npy
# Pop/Rock
#
# 2007 : 406 songs
# ===============================
# Topic: 0
# Death Valley High
# 0_Lovers.npy
# Pop/Rock
#
# Topic: 1
# Charmaine Neville
# 0_With You in Mind.npy
# Jazz
#
# Topic: 2
# A Static Lullaby
# 0_Hang 'Em High.npy
# Pop/Rock
#
# Topic: 3
# Jose Conde y Ola Fresca
# 0_Pititi y Titi.npy
# International
#
# Topic: 4
# Gift of Gab
# 0_All Night (Intro)Watch Out!.npy
# Rap
#
# 2008 : 410 songs
# ===============================
# Topic: 0
# Sean Kingston
# 0_Roll.npy
# Rap
#
# Topic: 1
# Vic Juris
# 0_Black Satin.npy
# Jazz
#
# Topic: 2
# Katatonia
# 0_July.npy
# Pop/Rock
#
# Topic: 3
# Kleeer
# 0_Tonight.npy
# R&B;
#
# Topic: 4
# Sean Kingston
# 0_Roll.npy
# Rap
#
# 2009 : 318 songs
# ===============================
# Topic: 0
# The Mars Volta
# 0_Wax Simulacra.npy
# Pop/Rock
#
# Topic: 1
# Mason Proper
# 0_Miss Marylou Carreau.npy
# Pop/Rock
#
# Topic: 2
# Old Haunts
# 0_Volatile.npy
# Pop/Rock
#
# Topic: 3
# Ani DiFranco
# 0_City That Care Forgot.npy
# Pop/Rock
#
# Topic: 4
# Flight of the Conchords
# 0_Business Time.npy
# Comedy/Spoken
#
# 2010 : 350 songs
# ===============================
# Topic: 0
# Solex
# 0_The Uppercut.npy
# Electronic
#
# Topic: 1
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# Topic: 2
# Tego Calderón
# 0_You Slip, She Grip.npy
# Rap
#
# Topic: 3
# Chantal Kreviazuk
# 0_Half of Me.npy
# Easy Listening
#
# Topic: 4
# Reflection Eternal
# 0_In the Red.npy
# Rap
#
# 2011 : 272 songs
# ===============================
# Topic: 0
# Teedra Moses
# 0_Self Made.npy
# R&B;
#
# Topic: 1
# Millie Small
# 0_Hey Boy, Hey Girl.npy
# Reggae
#
# Topic: 2
# Sarah Silverman
# 0_Blind Woman Blues.npy
# Comedy/Spoken
#
# Topic: 3
# Los Tigres del Norte
# 0_Jefe De Jefes.npy
# Latin
#
# Topic: 4
# Teedra Moses
# 0_Self Made.npy
# R&B;
#
# 2012 : 299 songs
# ===============================
# Topic: 0
# J Dilla
# 0_E=MC2.npy
# Rap
#
# Topic: 1
# Sutton Foster
# 0_Friendship.npy
# Stage & Screen
#
# Topic: 2
# Michael Calfan
# 0_The Wave [Thomas Gold Remix Edit].npy
# Electronic
#
# Topic: 3
# Esperanza Spalding
# 0_Crowned & Kissed.npy
# Jazz
#
# Topic: 4
# Suburban Legends
# 0_Powerful Game.npy
# Pop/Rock
#
# 2013 : 377 songs
# ===============================
# Topic: 0
# Carl Thomas
# 0_One Name.npy
# R&B;
#
# Topic: 1
# Arctic Monkeys
# 0_Do I Wanna Know?.npy
# Pop/Rock
#
# Topic: 2
# Ha Ha Tonka
# 0_Lessons.npy
# Pop/Rock
#
# Topic: 3
# Prefab Sprout
# 0_Devil Came a Calling.npy
# Pop/Rock
#
# Topic: 4
# Carl Thomas
# 0_One Name.npy
# R&B;
#
# 2014 : 390 songs
# ===============================
# Topic: 0
# Royce da 5'9"
# 0_Detroit vs. Everybody.npy
# Rap
#
# Topic: 1
# Shift K3Y
# 0_Make It Good.npy
# Electronic
#
# Topic: 2
# Ume
# 0_Black Stone.npy
# Pop/Rock
#
# Topic: 3
# Lord RAJA
# 0_Gottfried Semper.npy
# Electronic
#
# Topic: 4
# DJ Quik
# 0_Shine.npy
# Rap
#
# 2015 : 277 songs
# ===============================
# Topic: 0
# Tigercats
# 0_Junior Champion.npy
# Pop/Rock
#
# Topic: 1
# Elvis Perkins
# 0_Moon Woman, Pt. 2.npy
# Pop/Rock
#
# Topic: 2
# Walter Hyatt
# 0_Motor City Man.npy
# Country
#
# Topic: 3
# Lil Bibby
# 0_Models & Bottles.npy
# Rap
#
# Topic: 4
# Newton Faulkner
# 0_Get Free.npy
# Pop/Rock
#
# 2016 : 264 songs
# ===============================
# Topic: 0
# Boys Like Girls
# 0_The Great Escape.npy
# Pop/Rock
#
# Topic: 1
# Cuong Vu
# 0_Acid Kiss.npy
# Jazz
#
# Topic: 2
# Macklemore & Ryan Lewis
# 0_Downtown.npy
# Rap
#
# Topic: 3
# Eddie Bo
# 0_St. James Infirmary.npy
# R&B;
#
# Topic: 4
# Dip in the Pool
# 0_On Retinae [East Version].npy
# Pop/Rock
#
# 2017 : 188 songs
# ===============================
# Topic: 0
# Betty Davis
# 0_Anti Love Song.npy
# R&B;
#
# Topic: 1
# Braxton Cook
# 0_FJYD.npy
# Jazz
#
# Topic: 2
# ORB
# 0_Hazelwart.npy
# Pop/Rock
#
# Topic: 3
# The Frightnrs
# 0_Nothing More to Say.npy
# Pop/Rock
#
# Topic: 4
# The Frightnrs
# 0_Nothing More to Say.npy
# Pop/Rock
#
# 2018 : 3 songs
# ===============================
# Topic: 0
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 1
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 2
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 3
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock
#
# Topic: 4
# The Black Dahlia Murder
# 0_Catacomb Hecatomb.npy
# Pop/Rock

# %% [markdown]
# # Correlation with AllMusic Influence Graph Degree

# %%
# Calculate max DIM influence per artist
max_dim_influences = np.array(song_topic_inf_matrix).max(axis=1)

# Get list of artist outdegrees in same order
artist_ids_ordered = [t[0] for t in bow_path_by_artist]
outdegrees_ordered = []

for id in artist_ids_ordered:
    outdegrees_ordered.append(artists[artists['id'] == id]['outdegree'].iloc[0])

# %%
# Calculate correlation
spearmanr(max_dim_influences, outdegrees_ordered)
# Out:
# SpearmanrResult(correlation=0.045207863759497452, pvalue=1.6639959398157967e-07)

# %% [markdown]
# # TODO: Baseline

# %% [markdown]
# # TODO: Breakdown by Genre
